# %%
# Adjusting the code cells
# Note: This is only valid for the current notebook!

from IPython.core.display import display, HTML
display(HTML("<style>.container {width:90% !important; } </style>"))
# Out:
# <style>.container {width:90% !important; } </style>

# %%
import pandas as pd
import mitosheet

# %%
df_bra = pd.read_csv('brazzers_df_csv')

# %%
df_bra
# Out:
#               Site Name      Pornstar 1           Pornstar 2  \
# 0        Baby Got Boobs     Alexis Ford     only Alexis Ford
# 1        Baby Got Boobs     Alexis Ford     only Alexis Ford
# 2        Baby Got Boobs     Alexis Ford     only Alexis Ford
# 3        Baby Got Boobs      Alexis May      only Alexis May
# 4        Baby Got Boobs    Allison Star    only Allison Star
# ...                 ...             ...                  ...
# 1567  Shes Gonna Squirt     Leya Falcon     only Leya Falcon
# 1568  Shes Gonna Squirt      Sophie Dee      only Sophie Dee
# 1569  Teens Like It Big    Layla London    only Layla London
# 1570  Teens Like It Big  Scarlett Jones  only Scarlett Jones
# 1571  Teens Like It Big      Stella Cox      only Stella Cox
#
#                                     Title  \
# 0                          Happy Boob Day
# 1                   Make It Up To My Dick
# 2               Xxx Men The Hellfire Club
# 3                       Video Store Whore
# 4                      Boobie Cunttestant
# ...                                   ...
# 1567                    The Squirt Locker
# 1568                   Squirt My Cockhole
# 1569           My Stepdaughter Loves Porn
# 1570  Curious Babysitter Gets Fucked Hard
# 1571      The Scoundrel Ruins A Sleepover
#
#                                                    Link
# 0     /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/baby_got_...
# 1     /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/baby_got_...
# 2     /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/baby_got_...
# 3     /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/baby_got_...
# 4     /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/baby_got_...
# ...                                                 ...
# 1567  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/shes_gonn...
# 1568  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/shes_gonn...
# 1569  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/teens_lik...
# 1570  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/teens_lik...
# 1571  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/teens_lik...
#
# [1572 rows x 5 columns]

# %%
mitosheet.sheet()
# Out:
# MitoWidget(analysis_name='UUID-918df730-c834-4779-be34-ac1ac070b790', code_json='{"imports": "from mitosheet i…
