# %% [markdown]
# ### File for loading the df of top56_ps and df_braz_complete for finding the missing titles..

# %%
import pandas as pd
df_top56_ps = pd.read_csv('df_top56_ps_tmp_08_08_22.csv', index_col=[0])
df_final_complete = pd.read_csv('db_final_complete.csv', index_col=[0])

# %%
len(df_final_complete)
# Out:
# 9522

# %%
df_final_complete[123:143]
# Out:
#                 Site                 PS1                  PS2  \
# 123  Brazzers Exxtra       aaliyah_hadid        michael_vegas
# 124  Brazzers Exxtra           aidra_fox          jessy_jones
# 125  Brazzers Exxtra      nicole_aniston           keiran_lee
# 126  Brazzers Exxtra           luna_star        victoria_june
# 127  Brazzers Exxtra        zara_du_rose        brooklyn_blue
# 128  Brazzers Exxtra         peta_jensen            eva_lovia
# 129  Brazzers Exxtra        rebecca_more  jordi_el_nino_polla
# 130  Brazzers Exxtra           luna_star        victoria_june
# 131  Brazzers Exxtra          stella_cox           keiran_lee
# 132  Brazzers Exxtra      vanessa_decker              danny_d
# 133  Brazzers Exxtra       abella_danger       alberto_blanco
# 134  Brazzers Exxtra        alicia_amira              danny_d
# 135  Brazzers Exxtra  gabriella_paltrova        casey_calvert
# 136  Brazzers Exxtra        kayla_kayden           keiran_lee
# ...

# %%
df_top56_ps.head()
# Out:
#                    Site           PS1      PS2                         Title  \
# 99   Big Tits At School  Abbey Brooks  No Name      cultural_festishism_720p
# 245    Big Tits At Work  Abbey Brooks  No Name    handling_his_business_720p
# 246    Big Tits At Work  Abbey Brooks  No Name        language_banguage_720p
# 247    Big Tits At Work  Abbey Brooks  No Name     sensitivity_training_720p
# 443  Big Tits In Sports  Abbey Brooks  No Name  taking_care_of_the_team_720p
#
#          PS3      PS4      PS5      PS6      PS7      PS8      PS9     PS10  \
# 99   No Name  No Name  No Name  No Name  No Name  No Name  No Name  No Name
# 245  No Name  No Name  No Name  No Name  No Name  No Name  No Name  No Name
# 246  No Name  No Name  No Name  No Name  No Name  No Name  No Name  No Name
# 247  No Name  No Name  No Name  No Name  No Name  No Name  No Name  No Name
# 443  No Name  No Name  No Name  No Name  No Name  No Name  No Name  No Name
#
# ...

# %%
# VERY important function to search on dataframes
def search(dataFrame, search_string):
    mask = (dataFrame.applymap(lambda x: isinstance(x, str) and search_string in x)).any(1)
    return dataFrame[mask]
