# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
from scan_func import scan_func
import os
import pandas as pd

# %%
def indices(lst, element):
    result = []
    offset = -1
    while True:
        try:
            offset = lst.index(element, offset+1)
            #print(offset)
        except ValueError:
            return result
        result.append(offset)

# %%
number = range(1,29)

root_site = 'https://www.brazzers.com/videos/site/81/real-wife-stories/page/'
page_content_db = pd.DataFrame()
page_number_db = {}
page_content_tmp = {}
page_columns = []

for lf in number:
    actual_site = root_site + str(lf)
    page_number = actual_site.split('/')[-2] + '/' + actual_site.split('/')[-1]
    page_number = page_number.replace('/', '_')
    print('page_number: ', page_number) 
    db_page_tmp = scan_func(actual_site)
    for lf in db_page_tmp:
        indxs = indices(db_page_tmp, '/joinf')
        db_page_tmp_sliced = db_page_tmp[indxs[0]+1:indxs[-1]]
        
        db_tmp_final = []
        for lf1 in db_page_tmp_sliced:
            if lf1.startswith('/video/'):
                lf_tmp = lf1.split('/')[-1].replace('-', '_')
                db_tmp_final.append(lf_tmp)
    
    mylist = list(dict.fromkeys(db_tmp_final)) 
    #print('mylist: ', mylist)
    page_content_tmp = pd.DataFrame(mylist)
    #print('type(page_content_tmp: ', type(page_content_tmp))
    #print('page_content_tmp: ', page_content_tmp)
    page_columns.append(page_number)
    page_content_db = pd.concat([page_content_db, page_content_tmp])
    
#page_content_db.columns = page_columns
# Out:
# page_number:  page_1
# scanning Site: https://www.brazzers.com/videos/site/81/real-wife-stories/page/1, Response: <Response [200]>
# page_number:  page_2
# scanning Site: https://www.brazzers.com/videos/site/81/real-wife-stories/page/2, Response: <Response [200]>
# page_number:  page_3
# scanning Site: https://www.brazzers.com/videos/site/81/real-wife-stories/page/3, Response: <Response [200]>
# page_number:  page_4
# scanning Site: https://www.brazzers.com/videos/site/81/real-wife-stories/page/4, Response: <Response [200]>
# page_number:  page_5
# scanning Site: https://www.brazzers.com/videos/site/81/real-wife-stories/page/5, Response: <Response [200]>
# page_number:  page_6
# scanning Site: https://www.brazzers.com/videos/site/81/real-wife-stories/page/6, Response: <Response [200]>
# page_number:  page_7
# scanning Site: https://www.brazzers.com/videos/site/81/real-wife-stories/page/7, Response: <Response [200]>
# page_number:  page_8
# ...

# %%
page_content_db
page_content_db.columns = ['rws_page']
page_content_db.index = range(0,len(page_content_db))

# %%
rws_page_content_complete = list(page_content_db['rws_page'])

# %%
rws_page_content_complete
# Out:
# ['tailored_to_your_liking',
#  'willing_to_pay',
#  'angelas_house_of_hedonism_part_3',
#  'angelas_house_of_hedonism_part_1',
#  'cheating_wife_is_dtf',
#  'fucking_my_old_bully',
#  'stealing_some_cock',
#  'phoenix_is_a_bad_bad_wife',
#  'what_romantic_evening',
#  'sex_addict_therapy',
#  'hot_ride_for_sale',
#  'wet_wife',
#  'honey_go_get_the_condoms',
#  'i_swear_i_love_my_husband',
#  'appraising_her_ass',
#  'my_wifes_a_slut',
#  'anal_with_her_sisters_husband',
#  'cafe_chic',
#  'letting_a_stranger_come_in',
#  'getting_her_husband_a_raise',
#  'caught_naked_for_strangers',
#  'alone_and_waiting',
#  'fuck_my_wife_while_i_watch',
#  'rich_bitch_shoe_fits',
#  'pussy_is_served',
#  'dressed_to_empress',
#  'an_escort_for_her_anniversary',
#  'i_cant_im_married',
#  'fuck_me_my_meeting',
#  'while_husbands_away',
#  'lexis_thanksgiving_stuffing',
#  'cheating_whore',
#  'blindfolded_cheater',
#  'cheating_husband_gets_cucked',
#  'how_could_you',
#  'bump_in_the_night',
# ...

# %%
4*24
# Out:
# 96

# %%
bra_csv = pd.read_csv('bra_final_py.csv')

# %%
selected_df = bra_csv[(bra_csv['Site'] == 'Real Wife Stories')]['Title']

# %%
selected_df
# Out:
# 1408                     the_dinner_party_1080p
# 1409                           warm_welcum_720p
# 1410                  ours_son_girlfriend_1080p
# 1411                  he_makes_wifey_watch_720p
# 1412                speed_swingers_delight_480p
#                          ...
# 1544    i_think_someones_banging _my_wife_1080p
# 1689                   one_soggy_afternoon_720p
# 1690                                     1_720p
# 1691                  in_lawful_infidelity_720p
# 1692                     upgrading_my_room_720p
# Name: Title, Length: 141, dtype: object

# %%
rws_csv_content = ['_'.join(x.split('_')[:-1]) for x in selected_df]

# %%
rws_page_content_complete

# %%
len(rws_page_content_complete)
# Out:
# 655

# %%
rws_csv_content
# Out:
# ['the_dinner_party',
#  'warm_welcum',
#  'ours_son_girlfriend',
#  'he_makes_wifey_watch',
#  'speed_swingers_delight',
#  'anal_time_for_my_valentine',
#  'swingers_on_vacation_part_2',
#  'swingers_on_vacation_part_1',
#  'real_ex_wives_of_beverly _hills',
#  'my_husbands_student_part_two',
#  'full_divorce_court_press',
#  'tierra_prohibida',
#  'squirting_swingers',
#  'alexis_youre_the_boss',
#  'reunion_romp',
#  'fappy_new_year',
#  'its_a_wonderful_sex_life',
#  'you_gotta_help_my_wife',
#  'swing_fling_part_2',
#  'naughty_neighbors',
#  'a_dick_before_divorce',
#  'had_some_fun_gotta_run',
#  'lick_my_limo',
#  'take_a_seat_on_my_dick_2',
#  'the_anniversary_she_ll_never_forget',
#  'walkin_on_cumshine',
#  'wife_showers_with_the_babysitter',
#  'sharing_is_caring',
#  'double_timing_wart_part_2',
#  'double_timing_wife_part_3',
#  'mr_woodman_says_hello',
#  'stay_away_from_my_daughter_part_2',
#  'sucking_the_sitter',
#  'survey_my_pussy',
#  'youre_busted_im_busty',
# ...

# %%
sub = 'pussy_pop_psychology'
print(any(sub in lf for lf in rws_page_content_complete))
# Out:
# True

# %%
ttm = 'pussy_pop_psychology

# %%
'_'.join(ttm.split('_')[:-1])
# Out:
# 'happy_boob_day'

# %%
selected_df = bra_csv[(bra_csv['Site'] == 'Real Wife Stories')]['Title']
#bra_csv['Title', 'site'='Real Wife Stories]

# %%
selected_df

# %%
bra_csv = pd.read_csv('bra_final_py.csv')

# %%
bra_csv_rws = [x.split('_')[-1] for x in bra_csv['Title']]

# %%
bra_csv['Title']

# %%
sub = 'one_last_shot'
for text in ttt:
    if sub in text:
        print(text)

# %%
page_content_db

# %%
page_db

# %%
for lf in db_rws_18:
    offset = -1
    if lf == '/joinf':
        offset = db_rws_18.index(lf, offset+1)
db_rws_18_sliced = db_rws_18[db_rws_18.index(lf)+1:]

# %%
def indices(lst, element):
    result = []
    offset = -1
    while True:
        try:
            offset = lst.index(element, offset+1)
            print(offset)
        except ValueError:
            return result
        result.append(offset)

# %%
indxs = indices(db_rws_18, '/joinf')

# %%
db_2 = db_rws_18[indxs[0]+1:indxs[-1]]

# %%
db_3 = []
for lf in db_2:
    if lf.startswith('/video/'):
        db_3.append(lf)

# %%
set(db_3)

# %%
mylist = ["a", "b", "a", "c", "c"]
mylist = dict.fromkeys(mylist)
print(mylist)

# %%
mylist = ["a", "b", "a", "c", "c"]
mylist = list(dict.fromkeys(mylist))
print(mylist)

# %%
video_string = "video"
ps_string = "pornstar"

title_db = []
g xmlns="http://www.w3.org/2000/svg" width="14" height="14" viewBox="0 0 24 24" fill="none" stroke="currentColor" stroke-width="2" stroke-linecap="round" stroke-linejoin="round" class="dtkdna-30 ZwYAZ"><path d="M1 12s4-8 11-8 11 8 11 8-4 8-11 8-11-8-11-8z"></path><circle cx="12" cy="12" r="3"></circle></svg></span><span><div style="margin-left: auto;"><span>99%</span><svg xmlns="http://www.w3.org/2000/svg" width="14" height="14" viewBox="0 0 24 24" fill="none" stroke="currentColor" stroke-width="2" stroke-linecap="round" stroke-linejoin="round" class="dtkdna-19 eAXnOG"><path d="M20.84 4.61a5.5 5.5 0 0 0-7.78 0L12 5.67l-1.06-1.06a5.5 5.5 0 0 0-7.78 7.78l1.06 1.06L12 21.23l7.78-7.78 1.06-1.06a5.5 5.5 0 0 0 0-7.78z"></path></svg></div></span></div><div class="dtkdna-4 beTNiV dtkdna-10 dGJrBo"><div color="#D6D6D6" class="i4pbj6-0 dImjYt"><span class="i4pbj6-1 gDWxqP" style="left: 0px;"><a href="/video/4007341/sister-swap-part-1" title="Sister Swap: Part 1">Sister Swap: Part 1</a></span></div></div></div></div></div></div><div><ul class="sowzbh-0 iLRcYB vlgkf8-0 iBFqXH"><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">«</a></li><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">‹</a></li><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">7</a></li><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">8</a></li><li class="sowzbh-1 gjRQwQ"><span class="sowzbh-2 eSqdzJ">9</span></li><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">10</a></li><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">11</a></li><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">›</a></li><li class="sowzbh-1 gjRQwQ"><a href="#" class="sowzbh-2 jRVyEV">»</a></li></ul></div></div></section>

#data_page_2 = soup_tmp.find_all('section')
# data_page_2 = soup_tmp.find_all('div')
# for link in data_page_tmp:
#     db.append(link.get('href'))
    
# for link in data_page_2:
#     db.append(link.get('href'))

# # for lf in db:
# #     if video_string in lf:
# #         title_db.append(lf)
# #     if ps_string in lf:
# #         ps_name_db.append(lf)

# #print('db: ', db)
# # print('title_db = ', title_db)
# #print('ps_name_db = ', ps_name_db)


# title_dummy = "/videos/"

# for ele_ in title_db:
#     if (ele_ == title_dummy):
#         title_db.remove(ele_)

# #title_db.pop(0)

# title_db_tmp = []


# for lf in title_db:
#     if lf not in title_db_tmp:
#         title_db_tmp.append(lf)

# # ps_name_db_tmp = []
# # ps_dummy_1 = "/pornstars/"
# # ps_dummy_2 = '/pornstars/gender/female/'
# # ps_dummy_3 = '/pornstars/gender/male/'
# # for ps_ in ps_name_db:
# #     if (ps_ == ps_dummy_1):
# #         ps_name_db.remove(ps_)

# # for ps_ in ps_name_db:
# #     if (ps_ == ps_dummy_2):
# #         ps_name_db.remove(ps_)

# # for ps_ in ps_name_db:
# #     if (ps_ == ps_dummy_3):
# #         ps_name_db.remove(ps_)
# # for lf in ps_name_db:
# #     if lf not in ps_name_db_tmp:
# #         ps_name_db_tmp.append(lf)

# %%
data_page_2 = soup_tmp.find_all('section')

# %%
for link in data_page_2:
    db.append(link.get('href'))

# %%
db_rws_18 = scan_func('https://www.brazzers.com/videos/site/81/real-wife-stories/page/18')

# %%
#db_tmp = [lf2 for lf2 in db_rws_18 if lf2.startswith('/')]
for lf in db_rws_18:
    print('lf: ', lf)

# %%
type(db_rws_18)

# %%
title_db_tmp

# %%
db_1 = np.array(db[15:])

# %%
for ele_ in title_db:
    if (ele_ == title_dummy):
        title_db.remove(ele_)

# %%
title_db

# %%
for lf_strg in db_1:
    if lf_strg.startswith('/video'):
        print(np.where(db_1 == lf_strg))
#strg = "/video/4506761/tailored-to-your-liking"
#np.where(db_1 == strg)
