# %% [markdown]
# ### Definition of the relevant modules

# %%
import pandas as pd
import math
import sys
from termcolor import colored
from functools import reduce
from itertools import chain
sys.path.append('/Users/joerg/repos/braz')
from utilities_functions import scan_func
# To run all commands within one cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_rows', 1000)
# default behaviour:
# InteractiveShell.ast_node_interactivity = "last_expr"

# %% [markdown]
# ***

# %% [markdown]
# ### Importing the temporary final df

# %%
df_old = pd.read_csv('df_edited_tmp.csv', index_col=[0])
df_new = pd.read_csv('final_df_11_04_2022.csv', index_col=[0])

# %% [markdown]
# Delete the unwanted column "Unnamed: 0" by reading the df one time and then export this
# under another csv-file...

# %%
# Take all cells at columns "PS1" which are not NaN!
df_old = df_old[df_old['PS1'].notna()]
df_new = df_new[df_new['PS1'].notna()]

# %%
df_new.tail()
# Out:
#            Site          PS1             PS2                       Title
# 9714  Zz Series   riley_reid       mick_blue          brazzi_bots_part_1
# 9715  Zz Series  cali_carter     small_hands  brazzibots_uprising_part_3
# 9716  Zz Series     karma_rx       lela_star          brazzi_bots_part_4
# 9717  Zz Series  abigail_mac  nicolette_shea          brazzi_bots_part_2
# 9718  Zz Series    lela_star   xander_corvus          brazzi_bots_part_3

# %%
df_old.tail()
# Out:
#            Site          PS1             PS2  \
# 9435  Zz Series   riley_reid       mick_blue
# 9436  Zz Series     lulu_chu       mick_blue
# 9437  Zz Series     karma_rx       lela_star
# 9438  Zz Series  abigail_mac  nicolette_shea
# 9439  Zz Series    lela_star   xander_corvus
#
#                                     Title Available
# 9435                   brazzi_bots_part_1        No
# 9436  kinky_secrets_of_the_suburbs_part_2        No
# 9437                   brazzi_bots_part_4        No
# 9438                   brazzi_bots_part_2        No
# 9439                   brazzi_bots_part_3        No

# %% [markdown]
# # Search masks ..

# %%
def styling_specific_cell(x,row_idx,col_idx):
    color = 'background-color: yellow; color: violet'
    df_styler = pd.DataFrame('', index=x.index, columns=x.columns)
    df_styler.iloc[row_idx, col_idx] = color
    return df_styler

# %%
df['Available'] = 'No'

# %% [markdown]
# ### df_old

# %%
# substr = "kinky_secrets_of_the_suburbs_part_4"
substr = 'jasmine_jae'

# substr_2 = 'everyones_favourite_visitor'
substr_2 = ''
colored_s = colored(substr_2, 'red')
df_old[df_old['PS1'].str.contains(substr) & df_old['Title'].str.contains(substr_2)]
ctn = len(df_old[df_old['PS1'].str.contains(substr) & df_old['Title'].str.contains(substr_2)])
print('ctn...: ', ctn)
#df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_2)].index.values.item()
#len(df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_2)])


#df_2.style.applymap(highlight_cell('bimbo'))

# len(df_2[df_2['PS1'].str.contains(substr)])
# Out:
#                        Site          PS1                  PS2  \
# 291         Brazzers Exxtra  jasmine_jae           keiran_lee
# 374         Brazzers Exxtra  jasmine_jae            marc_rose
# 707         Brazzers Exxtra  jasmine_jae              danny_d
# 1538  Big Butts Like It Big  jasmine_jae            mick_blue
# 1571  Big Butts Like It Big  jasmine_jae        markus_dupree
# 1644  Big Butts Like It Big  jasmine_jae              danny_d
# 2525     Big Tits At School  jasmine_jae           ryan_ryder
# 2847       Big Tits At Work  jasmine_jae         rebecca_more
# 2879       Big Tits At Work  jasmine_jae           keiran_lee
# 2981       Big Tits At Work  jasmine_jae              lou_lou
# 4591      Doctor Adventures  jasmine_jae           keiran_lee
# 4758      Doctor Adventures  jasmine_jae            jay_snake
# 6230        Mommy Got Boobs  jasmine_jae              danny_d
# 6295        Mommy Got Boobs  jasmine_jae  jordi_el_nino_polla
# 6985      Milfs Like It Big  jasmine_jae  jordi_el_nino_polla
# 7604  Pornstars Like It Big  jasmine_jae  jordi_el_nino_polla
# 7659  Pornstars Like It Big  jasmine_jae         rebecca_more
# 7742  Pornstars Like It Big  jasmine_jae              danny_d
# 7835  Pornstars Like It Big  jasmine_jae          porsha_sins
# 8127      Real Wife Stories  jasmine_jae      courtney_taylor
# 8326      Real Wife Stories  jasmine_jae              danny_d
# 8354      Real Wife Stories  jasmine_jae              danny_d
# 8674      Real Wife Stories  jasmine_jae         charles_dera
# 8734      Shes Gonna Squirt  jasmine_jae              danny_d
#
#                                           Title Available
# 291                 a_piece_of_jasmine_jaes_ass        No
# 374                             the_slutty_chef        No
# 707                   the_horniest_man_on_earth        No
# 1538                      to_assfuck_a_neighbor        No
# 1571                       assmissible_evidence        No
# 1644                              sexscape_room        No
# 2525                       giving_teacher_the_d        No
# 2847              office_4_play_viii_uk_edition        No
# 2879                              quid_pro_blow        No
# 2981                        parliamentary_pussy        No
# 4591                waking_up_the_comatose_cock        No
# 4758                  scaring_the_pants_off_him        No
# 6230                         tea_and_crump_tits        No
# 6295                       my_fucking_step_goal        No
# 6985         horsing_around_with_the_stable_boy        No
# 7604                                 the_agency        No
# 7659                  how_danny_d_stole_xxx_mas        No
# 7742                               benny_hilled        No
# 7835                keiran_lee_nympho_insomniac        No
# 8127  can_i_bother_you_for_a_tall_glass_of_dick        No
# 8326                          boning_the_butler        No
# 8354                   his_best_friends_bedding        No
# 8674                              you_messed_up        No
# 8734                  i_want_to_make_you_squirt        No
# ctn...:  24

# %% [markdown]
# ### df_new

# %%
# substr = "kinky_secrets_of_the_suburbs_part_4"
substr = 'jasmine_jae'

# substr_2 = 'everyones_favourite_visitor'
substr_2 = 'jasmine_jae'
text_str = ''
colored_s = colored(substr_2, 'red')
df_new[df_new['PS1'].str.contains(substr) | df_new['PS2'].str.contains(substr_2) & df_new['Title'].str.contains(text_str)]

ctn = len(df_new[df_new['PS1'].str.contains(substr) | df_new['PS2'].str.contains(substr_2) & df_new['Title'].str.contains(text_str)])
print('ctn...: ', ctn)
#df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_2)].index.values.item()
#len(df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_2)])


#df_2.style.applymap(highlight_cell('bimbo'))

# len(df_2[df_2['PS1'].str.contains(substr)])
# Out:
#                        Site           PS1                  PS2  \
# 38          Brazzers Exxtra   madison_ivy          jasmine_jae
# 155         Brazzers Exxtra   madison_ivy          jasmine_jae
# 293         Brazzers Exxtra   jasmine_jae           keiran_lee
# 375         Brazzers Exxtra   jasmine_jae            marc_rose
# 713         Brazzers Exxtra   jasmine_jae              danny_d
# 1575  Big Butts Like It Big   jasmine_jae            mick_blue
# 1608  Big Butts Like It Big   jasmine_jae        markus_dupree
# 1681  Big Butts Like It Big   jasmine_jae              danny_d
# 2605     Big Tits At School   jasmine_jae           ryan_ryder
# 2931       Big Tits At Work   jasmine_jae         rebecca_more
# 2962       Big Tits At Work   jasmine_jae           keiran_lee
# 3064       Big Tits At Work   jasmine_jae              lou_lou
# 3523     Big Tits In Sports  erica_fontes          jasmine_jae
# 4732      Doctor Adventures   jasmine_jae           keiran_lee
# 4899      Doctor Adventures   jasmine_jae            jay_snake
# 6445        Mommy Got Boobs   jasmine_jae              danny_d
# 6510        Mommy Got Boobs   jasmine_jae  jordi_el_nino_polla
# 6963        Moms In Control    stella_cox          jasmine_jae
# 7208      Milfs Like It Big   jasmine_jae  jordi_el_nino_polla
# 7829  Pornstars Like It Big   jasmine_jae  jordi_el_nino_polla
# 7885  Pornstars Like It Big   jasmine_jae         rebecca_more
# 7967  Pornstars Like It Big   jasmine_jae              danny_d
# 8063  Pornstars Like It Big   jasmine_jae          porsha_sins
# 8374      Real Wife Stories   jasmine_jae      courtney_taylor
# 8573      Real Wife Stories   jasmine_jae              danny_d
# 8601      Real Wife Stories   jasmine_jae              danny_d
# 8921      Real Wife Stories   jasmine_jae         charles_dera
# 8994      Shes Gonna Squirt   jasmine_jae              danny_d
# 9623              Zz Series   anissa_kate          jasmine_jae
#
#                                           Title
# 38                      tour_of_london_part_one
# 155          tour_of_london_part_one_remastered
# 293                 a_piece_of_jasmine_jaes_ass
# 375                             the_slutty_chef
# 713                   the_horniest_man_on_earth
# 1575                      to_assfuck_a_neighbor
# 1608                       assmissible_evidence
# 1681                              sexscape_room
# 2605                       giving_teacher_the_d
# 2931              office_4_play_viii_uk_edition
# 2962                              quid_pro_blow
# 3064                        parliamentary_pussy
# 3523                     world_cup_uk_team_tits
# 4732                waking_up_the_comatose_cock
# 4899                  scaring_the_pants_off_him
# 6445                         tea_and_crump_tits
# 6510                       my_fucking_step_goal
# 6963      bringing_stepsiblings_closer_together
# 7208         horsing_around_with_the_stable_boy
# 7829                                 the_agency
# 7885                  how_danny_d_stole_xxx_mas
# 7967                               benny_hilled
# 8063                keiran_lee_nympho_insomniac
# 8374  can_i_bother_you_for_a_tall_glass_of_dick
# 8573                          boning_the_butler
# 8601                   his_best_friends_bedding
# 8921                              you_messed_up
# 8994                  i_want_to_make_you_squirt
# 9623           storm_of_kings_xxx_parody_part_1
# ctn...:  29

# %% [markdown]
# #### next... select only the PS1

# %%
search_ps1_string = 'jasmine_jae'
# substr_2 = 'everyones_favourite_visitor'
# if only the PS1 is searched, then set the substr_2 to '' !
search_title_string = ''

df[df['PS1'].str.contains(search_ps1_string) & df['Title'].str.contains(search_title_string)]
print('len..: ', len(df[df['PS1'].str.contains(search_ps1_string) & df['Title'].str.contains(search_title_string)]))
# Out:
#                        Site          PS1                  PS2  \
# 291         Brazzers Exxtra  jasmine_jae           keiran_lee
# 374         Brazzers Exxtra  jasmine_jae            marc_rose
# 707         Brazzers Exxtra  jasmine_jae              danny_d
# 1538  Big Butts Like It Big  jasmine_jae            mick_blue
# 1571  Big Butts Like It Big  jasmine_jae        markus_dupree
# 1644  Big Butts Like It Big  jasmine_jae              danny_d
# 2525     Big Tits At School  jasmine_jae           ryan_ryder
# 2847       Big Tits At Work  jasmine_jae         rebecca_more
# 2879       Big Tits At Work  jasmine_jae           keiran_lee
# 2981       Big Tits At Work  jasmine_jae              lou_lou
# 4591      Doctor Adventures  jasmine_jae           keiran_lee
# 4758      Doctor Adventures  jasmine_jae            jay_snake
# 6230        Mommy Got Boobs  jasmine_jae              danny_d
# 6295        Mommy Got Boobs  jasmine_jae  jordi_el_nino_polla
# 6985      Milfs Like It Big  jasmine_jae  jordi_el_nino_polla
# 7604  Pornstars Like It Big  jasmine_jae  jordi_el_nino_polla
# 7659  Pornstars Like It Big  jasmine_jae         rebecca_more
# 7742  Pornstars Like It Big  jasmine_jae              danny_d
# 7835  Pornstars Like It Big  jasmine_jae          porsha_sins
# 8127      Real Wife Stories  jasmine_jae      courtney_taylor
# 8326      Real Wife Stories  jasmine_jae              danny_d
# 8354      Real Wife Stories  jasmine_jae              danny_d
# 8674      Real Wife Stories  jasmine_jae         charles_dera
# 8734      Shes Gonna Squirt  jasmine_jae              danny_d
#
#                                           Title Available
# 291                 a_piece_of_jasmine_jaes_ass        No
# 374                             the_slutty_chef        No
# 707                   the_horniest_man_on_earth        No
# 1538                      to_assfuck_a_neighbor        No
# 1571                       assmissible_evidence        No
# 1644                              sexscape_room        No
# 2525                       giving_teacher_the_d        No
# 2847              office_4_play_viii_uk_edition        No
# 2879                              quid_pro_blow        No
# 2981                        parliamentary_pussy        No
# 4591                waking_up_the_comatose_cock        No
# 4758                  scaring_the_pants_off_him        No
# 6230                         tea_and_crump_tits        No
# 6295                       my_fucking_step_goal        No
# 6985         horsing_around_with_the_stable_boy        No
# 7604                                 the_agency        No
# 7659                  how_danny_d_stole_xxx_mas        No
# 7742                               benny_hilled        No
# 7835                keiran_lee_nympho_insomniac        No
# 8127  can_i_bother_you_for_a_tall_glass_of_dick        No
# 8326                          boning_the_butler        No
# 8354                   his_best_friends_bedding        No
# 8674                              you_messed_up        No
# 8734                  i_want_to_make_you_squirt        No
# len..:  24

# %% [markdown]
# evaluate the column number by hand... into the .at command!

# %%
df.at[8458,'Available'] = 'Yes'

# %%
df.to_csv('df_edited_tmp.csv')

# %% [markdown]
# set the corresponding column "available" to "yes"!

# %%
df.at[3069,'Available'] = 'Yes'

# %%
df.iloc[4010:4012,:]
# Out:
#                Site              PS1            PS2                  Title  \
# 4010  Big Wet Butts  lauren_phillips  ricky_johnson       soak_my_sundress
# 4011  Big Wet Butts     eva_angelina   rachel_starr  big_butt_extravaganza
#
#      Available
# 4010        No
# 4011       Yes

# %% [markdown]
# ***

# %% [markdown]
# ### Next: All entries of PS...

# %%
search_ps1_string = 'jasmine_jae'
search_ps2_string = 'jasmine_jae'
search_ps3_string = 'jasmine_jae'
# substr_2 = 'everyones_favourite_visitor'
# if only the PS1 is searched, then set the substr_2 to '' !
search_title_string = ''

df[df['PS1'].str.contains(search_ps1_string) | df['PS2'].str.contains(search_ps2_string) & df['Title'].str.contains(search_title_string)]
#print('len: ', len(df[df['PS1'].str.contains(search_ps1_string) | df['PS2'].str.contains(search_ps2_string) & df['Title'].str.contains(search_title_string)]))
# Out:
#                        Site           PS1                  PS2  \
# 38          Brazzers Exxtra   madison_ivy          jasmine_jae
# 154         Brazzers Exxtra   madison_ivy          jasmine_jae
# 291         Brazzers Exxtra   jasmine_jae           keiran_lee
# 374         Brazzers Exxtra   jasmine_jae            marc_rose
# 707         Brazzers Exxtra   jasmine_jae              danny_d
# 1538  Big Butts Like It Big   jasmine_jae            mick_blue
# 1571  Big Butts Like It Big   jasmine_jae        markus_dupree
# 1644  Big Butts Like It Big   jasmine_jae              danny_d
# 2525     Big Tits At School   jasmine_jae           ryan_ryder
# 2847       Big Tits At Work   jasmine_jae         rebecca_more
# 2879       Big Tits At Work   jasmine_jae           keiran_lee
# 2981       Big Tits At Work   jasmine_jae              lou_lou
# 3427     Big Tits In Sports  erica_fontes          jasmine_jae
# 4591      Doctor Adventures   jasmine_jae           keiran_lee
# 4758      Doctor Adventures   jasmine_jae            jay_snake
# 6230        Mommy Got Boobs   jasmine_jae              danny_d
# 6295        Mommy Got Boobs   jasmine_jae  jordi_el_nino_polla
# 6744        Moms In Control    stella_cox          jasmine_jae
# 6985      Milfs Like It Big   jasmine_jae  jordi_el_nino_polla
# 7604  Pornstars Like It Big   jasmine_jae  jordi_el_nino_polla
# 7659  Pornstars Like It Big   jasmine_jae         rebecca_more
# 7742  Pornstars Like It Big   jasmine_jae              danny_d
# 7835  Pornstars Like It Big   jasmine_jae          porsha_sins
# 8127      Real Wife Stories   jasmine_jae      courtney_taylor
# 8326      Real Wife Stories   jasmine_jae              danny_d
# 8354      Real Wife Stories   jasmine_jae              danny_d
# 8674      Real Wife Stories   jasmine_jae         charles_dera
# 8734      Shes Gonna Squirt   jasmine_jae              danny_d
# 9344              Zz Series   anissa_kate          jasmine_jae
#
#                                           Title Available
# 38                      tour_of_london_part_one        No
# 154          tour_of_london_part_one_remastered        No
# 291                 a_piece_of_jasmine_jaes_ass        No
# 374                             the_slutty_chef        No
# 707                   the_horniest_man_on_earth        No
# 1538                      to_assfuck_a_neighbor        No
# 1571                       assmissible_evidence        No
# 1644                              sexscape_room        No
# 2525                       giving_teacher_the_d        No
# 2847              office_4_play_viii_uk_edition        No
# 2879                              quid_pro_blow        No
# 2981                        parliamentary_pussy        No
# 3427                     world_cup_uk_team_tits        No
# 4591                waking_up_the_comatose_cock        No
# 4758                  scaring_the_pants_off_him        No
# 6230                         tea_and_crump_tits        No
# 6295                       my_fucking_step_goal        No
# 6744      bringing_stepsiblings_closer_together        No
# 6985         horsing_around_with_the_stable_boy        No
# 7604                                 the_agency        No
# 7659                  how_danny_d_stole_xxx_mas        No
# 7742                               benny_hilled        No
# 7835                keiran_lee_nympho_insomniac        No
# 8127  can_i_bother_you_for_a_tall_glass_of_dick        No
# 8326                          boning_the_butler        No
# 8354                   his_best_friends_bedding        No
# 8674                              you_messed_up        No
# 8734                  i_want_to_make_you_squirt        No
# 9344           storm_of_kings_xxx_parody_part_1        No

# %%
#df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_2)]
substr_3 = 'extra'
df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_3)].index.values.item()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-34bae9949bda> in <module>
#       1 #df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_2)]
#       2 substr_3 = 'extra'
# ----> 3 df[df['PS1'].str.contains(substr) & df['Title'].str.contains(substr_3)].index.values.item()
#
# NameError: name 'substr' is not defined

# %%
print(colored_s)

# %%
import sys
sys.executable

# %%
df_search.iloc[250:260]

# %%
idx_r = 251
idx_c = 3
df_search = df.style.apply(styling_specific_cell, row_idx = idx_r, col_idx = idx_c, axis = None)  # Axis set to None to work on entire dataframe

# %%
from termcolor import colored
from functools import reduce
from itertools import chain

text = 'left foot right foot left foot right. Feet in the day, feet at night.'
l1 = ['foot','feet']

print(reduce(lambda t, x: t.replace(*x), chain([text.lower()], ((t, colored(t,'white','on_red')) for t in l1))))

# %%
print(colored('hello', 'red'), colored('world', 'green'))

# %%
# Obosolete, because the values 'no_name' have been written 
# by the command: df_2['PS2'] = df_2['PS2'].fillna('no_name')!

#jb = df[(df['Site'] == 'Big Butts Like It Big') & (df['PS1'] == 'jasmine_black')].index.values.item()
jb_2 = df_2[(df_2['Site'] == 'Big Butts Like It Big') & (df_2['PS1'] == 'jasmine_black')].index.values.item()
# df_2.at[jb, 'PS2'] = 'no_name'

# ev = df[(df['Site'] == 'Big Butts Like It Big') & (df['PS1'] == 'erik_everhard')].index.values.item()
# df_2.at[ev, 'PS2'] = 'bridgette_b'

# jd = df[(df['Site'] == 'Big Butts Like It Big') & (df['PS1'] == 'james_deen') & (df['PS2'].isnull().values)].index.values.item()
# df_2.at[jd, 'PS2'] = 'no_name'

# js = df[(df['Site'] == 'Baby Got Boobs') & (df['PS1'] == 'johnny_sins') & (df['PS2'].isnull().values)].index.values.item()
# df_2.at[js, 'PS2'] = 'no_name'

# df_2_final = df_2.dropna()
# #del df_2_final['Unnamed: 0']

# %%
#len(df[df['Site'] == 'Brazzers Exxtra'])
df_2['Site'].value_counts()

# %%
for site, number in zip(db_sites[8:12], len_of_sites[8:12]):
    print('site: ', site)
    max_page_number = math.ceil(int(number) / 24)
    print('number: ', max_page_number)
#    for site_number in len_of_sites[8:10]:
#        tmp = range(1, int(site_number) +

# %%
root_site

# %%
from bs4 import BeautifulSoup
import requests
db = []
#url = 'https://www.brazzers.com/videos/site/62/doctor-adventures/sortby/views/page/'
url = 'https://www.brazzers.com/videos/site/82/big-butts-like-it-big/sortby/views/page/'
site_tmp = requests.get(url)

soup_tmp = BeautifulSoup(site_tmp.content, 'html.parser')

print(f'scanning Site: {url}, Response: {site_tmp}')

data_site_page = soup_tmp.find_all('a')

for lf in data_site_pageb:
    db.append(lf.get('href'))

# %%
368+183+171
# Out:
# 722

# %%
9387/723
# Out:
# 12.983402489626556

# %%
69+75+3+118+2+8+26+5+191+268+365
# Out:
# 1130

# %%
234+100+68+9+4+3+3+1
# Out:
# 422

# %%
13+12+351+101+217+64
# Out:
# 758

# %%
import os
CURRENT_PATH = os.path.dirname(__file__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4bc1dfbd44d3> in <module>
#       1 import os
# ----> 2 CURRENT_PATH = os.path.dirname(__file__)
#
# NameError: name '__file__' is not defined

# %%
pwd
# Out:
# '/Users/joerg/repos/braz/site_scans'
