# %% [markdown]
# ### Scan comparison between df_final and my_db

# %%
import pandas as pd
import math
import sys
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:90% !important; }</style>"))
sys.path.append('/Users/joerg/repos/braz')
from utilities_functions import scan_func
# To run all commands within one cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_rows', None)
# default behaviour:
# InteractiveShell.ast_node_interactivity = "last_expr"
# Out:
# <style>.container {width:90% !important; }</style>

# %% [markdown]
# #### Jasmine Jae

# %%
chosen_model_jasmine_jae = ['https://www.brazzers.com/videos/models/16357/jasmine-jae/page/']
max_page_len_of_sites_jj = [2]

# %%
page_content_db = pd.DataFrame()
page_number_db = {}
page_content_tmp = {}
page_columns = []
ps1_db = pd.DataFrame()
ps2_db = {}
title_db = {}
db_actual_site_name = pd.DataFrame()
db_final_tmp = pd.DataFrame()
db_actual_site_name_sliced = pd.DataFrame()

# Determination of the maximum number of pages
# for lf_root in db_sites[12:13]:
#     db_page_tmp_2 = scan_func(lf_root)
#     db_page_tmp_2 = [i for i in db_page_tmp if i.startswith('/videos/site/')]
#         print('db_page_tmp: ', db_page_tmp_2)

        
        
for root_site, number in zip(chosen_model_jasmine_jae[:], max_page_len_of_sites_jj):
    print('max..' , number)
  

    # max_page_number = math.ceil(int(number) / 24)
       
    for page_nr in range(1, int(number) + 1):
        print('page_nr: ', page_nr)
        actual_site = root_site + str(page_nr)
        site_name = actual_site.split('/')[-5].replace('-', ' ').title()
            
        #print('site_name: ', site_name)
        db_page_tmp = scan_func(actual_site)
        print('db_page_tmp: ', db_page_tmp)
        db_page_video = [i for i in db_page_tmp if i.startswith('/video/')]
        
        db_page_ps = [i for i in db_page_tmp if i.startswith('/pornstar/')]
        ps1 = [h.split('/')[-1].replace('-','_') for h in db_page_ps[::2]]
        ps2 = [h.split('/')[-1].replace('-', '_') for h in db_page_ps[1::2]]
        
        title = [h.split('/')[-1].replace('-', '_') for h in db_page_video[::2]]
        #print('title: ', title)
        site_tmp = [site_name]
        #print('site_tmp: ', site_name)
        site = list(site_tmp) * 24
        #print('site: ', site)
        
        
        ps1_db = pd.DataFrame(ps1)
        ps2_db = pd.DataFrame(ps2)
        title_db = pd.DataFrame(title)
        site_db = pd.DataFrame(site)
        print('Site_db: ', site_db)
        db_all_tmp = pd.concat([site_db, ps1_db, ps2_db, title_db], axis=1)
        custom_cols = ['Site', 'PS1', 'PS2', 'Title']
        #print('db_all_tmp: ', db_all_tmp)
        db_all_tmp.columns = custom_cols
        db_actual_site_name = pd.concat([db_actual_site_name, db_all_tmp])
        #print('db_all_tmp: ', db_all_tmp)
        #print('db_actual_site_name:\n ', db_actual_site_name)

    df_tmp = db_actual_site_name
    #print('db_actual_site_name: ', db_actual_site_name)
    
df_jj_tmp = db_actual_site_name
jasmine_jae_df = df_jj_tmp[df_jj_tmp['PS1'].notna()]
# Out:
# max.. 2
# page_nr:  1
# scanning Site: https://www.brazzers.com/videos/models/16357/jasmine-jae/page/1, Response: <Response [200]>
# db_page_tmp:  ['/home', 'https://site-ma.brazzers.com/', '/joinf', '/upcoming', '/series', '/videos', '/contractstars', '/pornstars?gender=female', '/pornstars?gender=male', '/pornstars', '/categories', '/sites', '/highlights', 'https://site-ma.brazzers.com/', '/joinf', '/video/4475291/the-horniest-man-on-earth', '/pornstar/16357/jasmine-jae', '/pornstar/22978/danny-d', '/video/4475291/the-horniest-man-on-earth', '/video/4462321/sexscape-room', '/pornstar/16357/jasmine-jae', '/pornstar/22978/danny-d', '/video/4462321/sexscape-room', '/video/4417790/his-best-friends-bedding', '/pornstar/16357/jasmine-jae', '/pornstar/22978/danny-d', '/video/4417790/his-best-friends-bedding', '/video/4416465/tour-of-london-part-one-remastered', '/pornstar/5313/madison-ivy', '/pornstar/16357/jasmine-jae', '/video/4416465/tour-of-london-part-one-remastered', '/video/4388353/you-messed-up', '/pornstar/16357/jasmine-jae', '/pornstar/2417/charles-dera', '/video/4388353/you-messed-up', '/video/4302501/my-fucking-step-goal', '/pornstar/16357/jasmine-jae', '/pornstar/527/jordi-el-nino-polla', '/video/4302501/my-fucking-step-goal', '/video/4282521/waking-up-the-comatose-cock', '/pornstar/16357/jasmine-jae', '/pornstar/8597/keiran-lee', '/video/4282521/waking-up-the-comatose-cock', '/video/3796331/assmissible-evidence', '/pornstar/16357/jasmine-jae', '/pornstar/23/markus-dupree', '/video/3796331/assmissible-evidence', '/video/3971481/tea-and-crump-tits', '/pornstar/16357/jasmine-jae', '/pornstar/22978/danny-d', '/video/3971481/tea-and-crump-tits', '/video/3973981/horsing-around-with-the-stable-boy', '/pornstar/16357/jasmine-jae', '/pornstar/527/jordi-el-nino-polla', '/video/3973981/horsing-around-with-the-stable-boy', '/video/4001341/boning-the-butler', '/pornstar/16357/jasmine-jae', '/pornstar/22978/danny-d', '/video/4001341/boning-the-butler', '/video/3993841/the-agency', '/pornstar/16357/jasmine-jae', '/pornstar/527/jordi-el-nino-polla', '/video/3993841/the-agency', '/video/3810301/the-slutty-chef', '/pornstar/16357/jasmine-jae', '/pornstar/3153/marc-rose', '/video/3810301/the-slutty-chef', '/video/4006141/can-i-bother-you-for-a-tall-glass-of-dick', '/pornstar/16357/jasmine-jae', '/pornstar/29325/courtney-taylor', '/video/4006141/can-i-bother-you-for-a-tall-glass-of-dick', '/video/3858521/quid-pro-blow', '/pornstar/16357/jasmine-jae', '/pornstar/8597/keiran-lee', '/video/3858521/quid-pro-blow', '/video/3987771/cock-of-duty-a-xxx-parody', '/pornstar/2273/monique-alexander', '/pornstar/6967/stella-cox', '/video/3987771/cock-of-duty-a-xxx-parody', '/video/3789401/storm-of-kings-xxx-parody-part-1', '/pornstar/1579/anissa-kate', '/pornstar/16357/jasmine-jae', '/video/3789401/storm-of-kings-xxx-parody-part-1', '/video/3966331/bringing-stepsiblings-closer-together', '/pornstar/6967/stella-cox', '/pornstar/16357/jasmine-jae', '/video/3966331/bringing-stepsiblings-closer-together', '/video/3798601/to-assfuck-a-neighbor', '/pornstar/16357/jasmine-jae', '/pornstar/247/mick-blue', '/video/3798601/to-assfuck-a-neighbor', '/video/3868281/un-tour-por-londres-primera-parte', '/pornstar/5313/madison-ivy', '/pornstar/16357/jasmine-jae', '/video/3868281/un-tour-por-londres-primera-parte', '/video/3809551/a-piece-of-jasmine-jaes-ass', '/pornstar/16357/jasmine-jae', '/pornstar/8597/keiran-lee', '/video/3809551/a-piece-of-jasmine-jaes-ass', '/video/3804151/keiran-lees-1000th-this-is-your-zz-life', '/pornstar/4015/nina-elle', '/pornstar/4137/chanel-preston', '/video/3804151/keiran-lees-1000th-this-is-your-zz-life', '/video/3851611/office-4-play-viii-uk-edition', '/pornstar/16357/jasmine-jae', '/pornstar/30435/rebecca-more', '/video/3851611/office-4-play-viii-uk-edition', '/video/3807951/tour-of-london-part-one', '/pornstar/5313/madison-ivy', '/pornstar/16357/jasmine-jae', '/video/3807951/tour-of-london-part-one', '/videos/models/16357/jasmine-jae/page/2/', '/videos/models/16357/jasmine-jae/page/2/', '/videos/models/16357/jasmine-jae/page/2/', 'https://www.brazzers.com/joinf' ...
# Site_db:           0
# 0   Models
# 1   Models
# 2   Models
# 3   Models
# 4   Models
# 5   Models
# 6   Models
# 7   Models
# 8   Models
# 9   Models
# 10  Models
# 11  Models
# 12  Models
# 13  Models
# 14  Models
# 15  Models
# 16  Models
# 17  Models
# 18  Models
# 19  Models
# 20  Models
# 21  Models
# 22  Models
# 23  Models
# page_nr:  2
# scanning Site: https://www.brazzers.com/videos/models/16357/jasmine-jae/page/2, Response: <Response [200]>
# db_page_tmp:  ['/home', 'https://site-ma.brazzers.com/', '/joinf', '/upcoming', '/series', '/videos', '/contractstars', '/pornstars?gender=female', '/pornstars?gender=male', '/pornstars', '/categories', '/sites', '/highlights', 'https://site-ma.brazzers.com/', '/joinf', '/video/3845091/parliamentary-pussy', '/pornstar/16357/jasmine-jae', '/pornstar/28605/lou-lou', '/video/3845091/parliamentary-pussy', '/video/3868241/world-cup-uk-team-tits', '/pornstar/8265/erica-fontes', '/pornstar/16357/jasmine-jae', '/video/3868241/world-cup-uk-team-tits', '/video/3897581/four-hands-to-jerk-the-clerk', '/pornstar/13933/emma-leigh', '/pornstar/16357/jasmine-jae', '/video/3897581/four-hands-to-jerk-the-clerk', '/video/3897631/scaring-the-pants-off-him', '/pornstar/16357/jasmine-jae', '/pornstar/37404/jay-snake', '/video/3897631/scaring-the-pants-off-him', '/video/3834801/giving-teacher-the-d', '/pornstar/16357/jasmine-jae', '/pornstar/23373/ryan-ryder', '/video/3834801/giving-teacher-the-d', '/video/3988901/how-danny-d-stole-xxx-mas', '/pornstar/16357/jasmine-jae', '/pornstar/30435/rebecca-more', '/video/3988901/how-danny-d-stole-xxx-mas', '/video/4014631/i-want-to-make-you-squirt', '/pornstar/16357/jasmine-jae', '/pornstar/22978/danny-d', '/video/4014631/i-want-to-make-you-squirt', '/video/3986401/benny-hilled', '/pornstar/16357/jasmine-jae', '/pornstar/22978/danny-d', '/video/3986401/benny-hilled', '/video/3993521/keiran-lee-nympho-insomniac', '/pornstar/16357/jasmine-jae', '/pornstar/42896/porsha-sins', '/video/3993521/keiran-lee-nympho-insomniac', '/videos/models/16357/jasmine-jae/', '/videos/models/16357/jasmine-jae/', '/videos/models/16357/jasmine-jae/', 'https://www.brazzers.com/joinf', 'https://twitter.com/Brazzers', 'https://www.instagram.com/stories/brazzersofficial/', 'https://www.adultforce.com/', 'https://www.brazzers.com/legal/privacy', 'https://support.brazzers.com/', 'https://support.brazzers.com/terms-of-service/', '/porn-sitemap', '/pages', '/about', '/press', 'https://www.adultforce.com/', 'https://www.brazzers.com/legal/privacy', 'https://support.brazzers.com/', 'https://support.brazzers.com/terms-of-service/', '/porn-sitemap', '/pages', '/about', '/press', 'https://www.brazzers.com/legal/2257', 'https://secure.vend-o.com/customers/profile/login/', 'https://probiller.com']
# Site_db:           0
# 0   Models
# 1   Models
# 2   Models
# 3   Models
# 4   Models
# 5   Models
# 6   Models
# 7   Models
# 8   Models
# 9   Models
# 10  Models
# 11  Models
# 12  Models
# 13  Models
# 14  Models
# 15  Models
# 16  Models
# 17  Models
# 18  Models
# 19  Models
# 20  Models
# 21  Models
# 22  Models
# 23  Models

# %%
jasmine_jae_df
# Out:
#       Site                PS1                  PS2  \
# 0   Models        jasmine_jae              danny_d
# 1   Models        jasmine_jae              danny_d
# 2   Models        jasmine_jae              danny_d
# 3   Models        madison_ivy          jasmine_jae
# 4   Models        jasmine_jae         charles_dera
# 5   Models        jasmine_jae  jordi_el_nino_polla
# 6   Models        jasmine_jae           keiran_lee
# 7   Models        jasmine_jae        markus_dupree
# 8   Models        jasmine_jae              danny_d
# 9   Models        jasmine_jae  jordi_el_nino_polla
# 10  Models        jasmine_jae              danny_d
# 11  Models        jasmine_jae  jordi_el_nino_polla
# 12  Models        jasmine_jae            marc_rose
# 13  Models        jasmine_jae      courtney_taylor
# 14  Models        jasmine_jae           keiran_lee
# 15  Models  monique_alexander           stella_cox
# 16  Models        anissa_kate          jasmine_jae
# 17  Models         stella_cox          jasmine_jae
# 18  Models        jasmine_jae            mick_blue
# 19  Models        madison_ivy          jasmine_jae
# 20  Models        jasmine_jae           keiran_lee
# 21  Models          nina_elle       chanel_preston
# 22  Models        jasmine_jae         rebecca_more
# 23  Models        madison_ivy          jasmine_jae
# 0   Models        jasmine_jae              lou_lou
# 1   Models       erica_fontes          jasmine_jae
# 2   Models         emma_leigh          jasmine_jae
# 3   Models        jasmine_jae            jay_snake
# 4   Models        jasmine_jae           ryan_ryder
# 5   Models        jasmine_jae         rebecca_more
# 6   Models        jasmine_jae              danny_d
# 7   Models        jasmine_jae              danny_d
# 8   Models        jasmine_jae          porsha_sins
#
#                                         Title
# 0                   the_horniest_man_on_earth
# 1                               sexscape_room
# 2                    his_best_friends_bedding
# 3          tour_of_london_part_one_remastered
# 4                               you_messed_up
# 5                        my_fucking_step_goal
# 6                 waking_up_the_comatose_cock
# 7                        assmissible_evidence
# 8                          tea_and_crump_tits
# 9          horsing_around_with_the_stable_boy
# 10                          boning_the_butler
# 11                                 the_agency
# 12                            the_slutty_chef
# 13  can_i_bother_you_for_a_tall_glass_of_dick
# 14                              quid_pro_blow
# 15                  cock_of_duty_a_xxx_parody
# 16           storm_of_kings_xxx_parody_part_1
# 17      bringing_stepsiblings_closer_together
# 18                      to_assfuck_a_neighbor
# 19          un_tour_por_londres_primera_parte
# 20                a_piece_of_jasmine_jaes_ass
# 21    keiran_lees_1000th_this_is_your_zz_life
# 22              office_4_play_viii_uk_edition
# 23                    tour_of_london_part_one
# 0                         parliamentary_pussy
# 1                      world_cup_uk_team_tits
# 2                four_hands_to_jerk_the_clerk
# 3                   scaring_the_pants_off_him
# 4                        giving_teacher_the_d
# 5                   how_danny_d_stole_xxx_mas
# 6                   i_want_to_make_you_squirt
# 7                                benny_hilled
# 8                 keiran_lee_nympho_insomniac

# %%
def search(dataFrame, search_string):
    mask = (dataFrame.applymap(lambda x: isinstance(x, str) and search_string in x)).any(1)
    return dataFrame[mask]

def search_only_one(dataFrame, search_string):
    mask = (dataFrame.applymap(lambda x: isinstance(x, str) and search_string in x)).any(1)
    print('tmmp: ', dataFrame[mask].iloc[0])
    return dataFrame[mask].iloc[0]

# %% [markdown]
# #### Load df_top56_ps for comparison

# %%
import pandas as pd
df_top56_ps = pd.read_csv('df_top56_ps_tmp_08_08_22.csv', index_col=[0])
df_complete = pd.read_csv('df_final_my_db_py_09_08_2022.csv', index_col=[0])

# %%
existing_titles_jj = pd.DataFrame()
zaehler = 0
for single_title_jj in jasmine_jae_df['Title'][:]:
    tmp=search_only_one(df_top56_ps, single_title_jj)
    #print('tmp: ', tmp)
    zaehler = zaehler+1
    print('zaehler: ', zaehler)
    existing_titles_jj = existing_titles_jj.append(tmp)
# Out:
# tmmp:  Site                                           Brazzers Extra
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                          the_horniest_man_on_earth_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                          WERDERNAS2X
# Link        /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/brazze...
# Name: 1640, dtype: object
# zaehler:  1
# tmmp:  Site                                    Big Butts Like It Big
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                                      sexscape_room_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_butts...
# Name: 69, dtype: object
# zaehler:  2
# tmmp:  Site                                        Real Wife Stories
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                           his_best_friends_bedding_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# Name: 1467, dtype: object
# zaehler:  3
# tmmp:  Site                                           Brazzers Extra
# PS1                                               Jasmine Jae
# PS2                                               Madison Ivy
# Title                 tour_of_london_part_one_remastered_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/brazzers_...
# Name: 716, dtype: object
# zaehler:  4
# tmmp:  Site                                        Real Wife Stories
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                                      you_messed_up_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# Name: 1468, dtype: object
# zaehler:  5
# tmmp:  Site                                          Mommy Got Boobs
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                               my_fucking_step_goal_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/mommy_got...
# Name: 1165, dtype: object
# zaehler:  6
# tmmp:  Site                                        Doctor Adventures
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                        waking_up_the_comatose_cock_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/doctor_ad...
# Name: 901, dtype: object
# zaehler:  7
# tmmp:  Site                                    Big Butts Like It Big
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                               assmissible_evidence_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_butts...
# Name: 68, dtype: object
# zaehler:  8
# tmmp:  Site                                          Mommy Got Boobs
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                                 tea_and_crump_tits_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/mommy_got...
# Name: 1166, dtype: object
# zaehler:  9
# tmmp:  Site                                        Milfs Like It Big
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                 horsing_around_with_the_stable_boy_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/milfs_lik...
# Name: 1030, dtype: object
# zaehler:  10
# tmmp:  Site                                        Real Wife Stories
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                                  boning_the_butler_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# Name: 1466, dtype: object
# zaehler:  11
# tmmp:  Site                                    Pornstars Like It Big
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                                         the_agency_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# Name: 1323, dtype: object
# zaehler:  12
# tmmp:  Site                                           Brazzers Extra
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                                    the_slutty_chef_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/brazzers_...
# Name: 715, dtype: object
# zaehler:  13
# tmmp:  Site                                        Real Wife Stories
# PS1                                               Jasmine Jae
# PS2                                           Courtney Taylor
# Title          can_i_bother_you_for_a_tall_glass_of_dick_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# Name: 1469, dtype: object
# zaehler:  14
# tmmp:  Site                                         Big Tits At Work
# PS1                                               Jasmine Jae
# PS2                                                   No Name
# Title                                      quid_pro_blow_720p
# PS3                                                   No Name
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# Name: 318, dtype: object
# zaehler:  15
# tmmp:  Site                                    Pornstars Like It Big
# PS1                                               Jasmine Jae
# PS2                                         Monique Alexander
# Title                          cock_of_duty_a_xxx_parody_720p
# PS3                                                Stella Cox
# PS4                                                   No Name
# PS5                                                   No Name
# PS6                                                   No Name
# PS7                                                   No Name
# PS8                                                   No Name
# PS9                                                   No Name
# PS10                                                  No Name
# Location                                           WERDERNASX
# Link        /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# Name: 1324, dtype: object
# zaehler:  16
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-df4ec7d1ad14> in <module>
#       2 zaehler = 0
#       3 for single_title_jj in jasmine_jae_df['Title'][:]:
# ----> 4     tmp=search_only_one(df_top56_ps, single_title_jj)
#       5     #print('tmp: ', tmp)
#       6     zaehler = zaehler+1
#
# <ipython-input-63-d984f1233a7d> in search_only_one(dataFrame, search_string)
#       5 def search_only_one(dataFrame, search_string):
#       6     mask = (dataFrame.applymap(lambda x: isinstance(x, str) and search_string in x)).any(1)
# ----> 7     print('tmmp: ', dataFrame[mask].iloc[0])
#       8     return dataFrame[mask].iloc[0]
#
# ~/opt/anaconda3/envs/python38/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/envs/python38/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# ~/opt/anaconda3/envs/python38/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
jasmine_jae_df.iloc[16]#['Title']
# Out:
# Site                               Models
# PS1                           anissa_kate
# PS2                           jasmine_jae
# Title    storm_of_kings_xxx_parody_part_1
# Name: 16, dtype: object

# %%
df_top56_ps[df_top56_ps['PS1'] == 'Jasmine Jae']
# Out:
#                       Site          PS1                PS2  \
# 354  Big Butts Like It Big  Jasmine Jae            No Name
# 355  Big Butts Like It Big  Jasmine Jae            No Name
# 356  Big Butts Like It Big  Jasmine Jae            No Name
# 357     Big Tits At School  Jasmine Jae            No Name
# 358       Big Tits At Work  Jasmine Jae            No Name
# 359       Big Tits At Work  Jasmine Jae        Leigh Darby
# 360       Big Tits At Work  Jasmine Jae            Lou Lou
# 361     Big Tits In Sports  Jasmine Jae       Erica Fontes
# 362     Big Tits In Sports  Jasmine Jae   Victoria Summers
# 364         Brazzers Extra  Jasmine Jae            No Name
# 365         Brazzers Extra  Jasmine Jae            No Name
# 366         Brazzers Extra  Jasmine Jae        Madison Ivy
# 368      Doctor Adventures  Jasmine Jae            No Name
# 369      Doctor Adventures  Jasmine Jae            No Name
# 370      Milfs Like It Big  Jasmine Jae            No Name
# 371        Mommy Got Boobs  Jasmine Jae            No Name
# 372        Mommy Got Boobs  Jasmine Jae            No Name
# 373        Moms In Control  Jasmine Jae         Stella Cox
# 375  Pornstars Like It Big  Jasmine Jae            No Name
# 376  Pornstars Like It Big  Jasmine Jae            No Name
# 377  Pornstars Like It Big  Jasmine Jae  Monique Alexander
# 378  Pornstars Like It Big  Jasmine Jae        Porsha Sins
# 379  Pornstars Like It Big  Jasmine Jae       Rebecca More
# 380      Real Wife Stories  Jasmine Jae            No Name
# 381      Real Wife Stories  Jasmine Jae            No Name
# 382      Real Wife Stories  Jasmine Jae            No Name
# 383      Real Wife Stories  Jasmine Jae    Courtney Taylor
# 384      Shes Gonna Squirt  Jasmine Jae            No Name
# 385         Brazzers Extra  Jasmine Jae            No Name
# 598       Big Tits At Work  Jasmine Jae        Leigh Darby
# 614         Brazzers Extra  Jasmine Jae        Madison Ivy
# 743       Big Tits At Work  Jasmine Jae        Leigh Darby
# 759  Pornstars Like It Big  Jasmine Jae       Rebecca More
# 862        Moms In Control  Jasmine Jae         Stella Cox
# 864  Pornstars Like It Big  Jasmine Jae  Monique Alexander
#
#                                               Title           PS3        PS4  \
# 354                       assmissible_evidence_720p       No Name    No Name
# 355                              sexscape_room_720p       No Name    No Name
# 356                      to_assfuck_a_neighbor_720p       No Name    No Name
# 357                      giving_teacher_the_d_1080p       No Name    No Name
# 358                              quid_pro_blow_720p       No Name    No Name
# 359             office_4_play_viii_uk_edition_1080p  Rebecca More  Tia Layne
# 360                       parliamentary_pussy_1080p       No Name    No Name
# 361                     world_cup_uk_team_tits_720p       No Name    No Name
# 362                                      rugby_720p       No Name    No Name
# 364                a_piece_of_jasmine_jaes_ass_720p       No Name    No Name
# 365                            the_slutty_chef_720p       No Name    No Name
# 366                    tour_of_london_part_one_720p       No Name    No Name
# 368                  scaring_the_pants_off_him_720p       No Name    No Name
# 369                waking_up_the_comatose_cock_720p       No Name    No Name
# 370         horsing_around_with_the_stable_boy_720p       No Name    No Name
# 371                       my_fucking_step_goal_720p       No Name    No Name
# 372                         tea_and_crump_tits_720p       No Name    No Name
# 373     bringing_stepsiblings_closer_together_1080p       No Name    No Name
# 375                               benny_hilled_720p       No Name    No Name
# 376                                 the_agency_720p       No Name    No Name
# 377                  cock_of_duty_a_xxx_parody_720p    Stella Cox    No Name
# 378               keiran_lee_nympho_insomniac_1080p       No Name    No Name
# 379                 how_danny_d_stole_xxx_mas_1080p       No Name    No Name
# 380                          boning_the_butler_720p       No Name    No Name
# 381                   his_best_friends_bedding_720p       No Name    No Name
# 382                              you_messed_up_720p       No Name    No Name
# 383  can_i_bother_you_for_a_tall_glass_of_dick_720p       No Name    No Name
# 384                  i_want_to_make_you_squirt_720p       No Name    No Name
# 385                  the_horniest_man_on_earth_720p       No Name    No Name
# 598             office_4_play_viii_uk_edition_1080p  Rebecca More  Tia Layne
# 614                    tour_of_london_part_one_720p       No Name    No Name
# 743             office_4_play_viii_uk_edition_1080p  Rebecca More  Tia Layne
# 759                 how_danny_d_stole_xxx_mas_1080p       No Name    No Name
# 862     bringing_stepsiblings_closer_together_1080p       No Name    No Name
# 864                  cock_of_duty_a_xxx_parody_720p    Stella Cox    No Name
#
#          PS5      PS6      PS7      PS8      PS9     PS10     Location  \
# 354  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 355  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 356  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 357  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 358  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 359  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 360  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 361  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 362  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 364  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 365  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 366  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 368  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 369  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 370  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 371  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 372  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 373  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 375  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 376  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 377  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 378  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 379  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 380  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 381  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 382  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 383  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 384  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 385  No Name  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 598  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 614  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 743  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 759  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 862  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 864  No Name  No Name  No Name  No Name  No Name  No Name   WERDERNASX
#
#                                                   Link
# 354  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_butts...
# 355  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_butts...
# 356  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_butts...
# 357  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 358  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 359  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 360  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 361  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 362  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 364  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/brazzers_...
# 365  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/brazzers_...
# 366  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/brazzers_...
# 368  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/doctor_ad...
# 369  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/doctor_ad...
# 370  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/milfs_lik...
# 371  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/mommy_got...
# 372  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/mommy_got...
# 373  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/moms_in_c...
# 375  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 376  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 377  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 378  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 379  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 380  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# 381  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# 382  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# 383  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/real_wife...
# 384  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/shes_gonn...
# 385  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/brazze...
# 598  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 614  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/brazzers_...
# 743  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 759  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 862  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/moms_in_c...
# 864  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...

# %%
jasmine_jae_df['Title']
# Out:
# 0                     the_horniest_man_on_earth
# 1                                 sexscape_room
# 2                      his_best_friends_bedding
# 3            tour_of_london_part_one_remastered
# 4                                 you_messed_up
# 5                          my_fucking_step_goal
# 6                   waking_up_the_comatose_cock
# 7                          assmissible_evidence
# 8                            tea_and_crump_tits
# 9            horsing_around_with_the_stable_boy
# 10                            boning_the_butler
# 11                                   the_agency
# 12                              the_slutty_chef
# 13    can_i_bother_you_for_a_tall_glass_of_dick
# 14                                quid_pro_blow
# 15                    cock_of_duty_a_xxx_parody
# 16             storm_of_kings_xxx_parody_part_1
# 17        bringing_stepsiblings_closer_together
# 18                        to_assfuck_a_neighbor
# 19            un_tour_por_londres_primera_parte
# 20                  a_piece_of_jasmine_jaes_ass
# 21      keiran_lees_1000th_this_is_your_zz_life
# 22                office_4_play_viii_uk_edition
# 23                      tour_of_london_part_one
# 0                           parliamentary_pussy
# 1                        world_cup_uk_team_tits
# 2                  four_hands_to_jerk_the_clerk
# 3                     scaring_the_pants_off_him
# 4                          giving_teacher_the_d
# 5                     how_danny_d_stole_xxx_mas
# 6                     i_want_to_make_you_squirt
# 7                                  benny_hilled
# 8                   keiran_lee_nympho_insomniac
# Name: Title, dtype: object

# %%
df_top56_ps.loc[373, :]

# %%
df_top56_ps.loc[862, :]

# %%
existing_titles_jj['Title']
# Out:
# 385                    the_horniest_man_on_earth_720p
# 355                                sexscape_room_720p
# 381                     his_best_friends_bedding_720p
# 382                                you_messed_up_720p
# 371                         my_fucking_step_goal_720p
# 369                  waking_up_the_comatose_cock_720p
# 354                         assmissible_evidence_720p
# 372                           tea_and_crump_tits_720p
# 370           horsing_around_with_the_stable_boy_720p
# 380                            boning_the_butler_720p
# 376                                   the_agency_720p
# 365                              the_slutty_chef_720p
# 383    can_i_bother_you_for_a_tall_glass_of_dick_720p
# 358                                quid_pro_blow_720p
# 377                    cock_of_duty_a_xxx_parody_720p
# 864                    cock_of_duty_a_xxx_parody_720p
# 373       bringing_stepsiblings_closer_together_1080p
# 862       bringing_stepsiblings_closer_together_1080p
# 356                        to_assfuck_a_neighbor_720p
# 364                  a_piece_of_jasmine_jaes_ass_720p
# 359               office_4_play_viii_uk_edition_1080p
# 598               office_4_play_viii_uk_edition_1080p
# 743               office_4_play_viii_uk_edition_1080p
# 366                      tour_of_london_part_one_720p
# 614                      tour_of_london_part_one_720p
# 360                         parliamentary_pussy_1080p
# 361                       world_cup_uk_team_tits_720p
# 367                 four_hands_to_jerk_the_clerk_720p
# 368                    scaring_the_pants_off_him_720p
# 357                        giving_teacher_the_d_1080p
# 379                   how_danny_d_stole_xxx_mas_1080p
# 759                   how_danny_d_stole_xxx_mas_1080p
# 384                    i_want_to_make_you_squirt_720p
# 375                                 benny_hilled_720p
# 378                 keiran_lee_nympho_insomniac_1080p
# Name: Title, dtype: object

# %%
df_old = df_1_tmp[df_1_tmp['PS1'].notna()]

# %%
len(df_old)

# %%
chosen_model_rebecca_more = ['https://www.brazzers.com/videos/models/30435/rebecca-more/page']
max_page_len_of_sites_rm = [1]

# %%
page_content_db = pd.DataFrame()
page_number_db = {}
page_content_tmp = {}
page_columns = []
ps1_db = pd.DataFrame()
ps2_db = {}
title_db = {}
db_actual_site_name = pd.DataFrame()
db_final_tmp = pd.DataFrame()
db_actual_site_name_sliced = pd.DataFrame()
        
for root_site, number in zip(chosen_model_rebecca_more[:], max_page_len_of_sites_rm):
    print('max..' , number)
       
    for page_nr in range(1, int(number) + 1):
        print('page_nr: ', page_nr)
        actual_site = root_site + str(page_nr)
        site_name = actual_site.split('/')[-5].replace('-', ' ').title()
            
        print('site_name: ', site_name)
        db_page_tmp = scan_func(actual_site)
        #print('db_page_tmp: ', db_page_tmp)
        db_page_video = [i for i in db_page_tmp if i.startswith('/video/')]
        
        db_page_ps = [i for i in db_page_tmp if i.startswith('/pornstar/')]
        ps1 = [h.split('/')[-1].replace('-','_') for h in db_page_ps[::2]]
        ps2 = [h.split('/')[-1].replace('-', '_') for h in db_page_ps[1::2]]
        
        title = [h.split('/')[-1].replace('-', '_') for h in db_page_video[::2]]
        #print('title: ', title)
        site_tmp = [site_name]
        #print('site_tmp: ', site_name)
        site = list(site_tmp) * 24
        #print('site: ', site)
        
        
        ps1_db = pd.DataFrame(ps1)
        ps2_db = pd.DataFrame(ps2)
        title_db = pd.DataFrame(title)
        site_db = pd.DataFrame(site)
        
        db_all_tmp = pd.concat([site_db, ps1_db, ps2_db, title_db], axis=1)
        custom_cols = ['Site', 'PS1', 'PS2', 'Title']
        #print('db_all_tmp: ', db_all_tmp)
        db_all_tmp.columns = custom_cols
        db_actual_site_name = pd.concat([db_actual_site_name, db_all_tmp])
        #print('db_all_tmp: ', db_all_tmp)
        #print('db_actual_site_name:\n ', db_actual_site_name)

    df_tmp = db_actual_site_name
    #print('df_tmp: ', db_actual_site_name)
    
df_1_tmp = db_actual_site_name
rebecca_more_df = df_1_tmp[df_1_tmp['PS1'].notna()]

# %%
def search(dataframe, item):
    mask = (dataframe.applymap(lambda x: isinstance(x, str) and item in x)).any(1)
    print(mask)
    return dataframe[mask]

# %%
search(rebecca_more_df, 'rebecca')

# %%
rebecca_more_df

# %%
#['https://www.brazzers.com/videos/models/30435/rebecca-more/page']
chosen_model_carmella_bing = ['https://www.brazzers.com/videos/models/2643/carmella-bing/page/']
max_page_len_of_sites_cb = [2]

# %%
page_content_db = pd.DataFrame()
page_number_db = {}
page_content_tmp = {}
page_columns = []
ps1_db = pd.DataFrame()
ps2_db = {}
title_db = {}
db_actual_site_name = pd.DataFrame()
db_final_tmp = pd.DataFrame()
db_actual_site_name_sliced = pd.DataFrame()
        
for root_site, number in zip(chosen_model_carmella_bing[:], max_page_len_of_sites_cb):
    print('max..' , number)
       
    for page_nr in range(1, int(number) + 1):
        print('page_nr: ', page_nr)
        actual_site = root_site + str(page_nr)
        site_name = actual_site.split('/')[-5].replace('-', ' ').title()
            
        print('site_name: ', site_name)
        db_page_tmp = scan_func(actual_site)
        #print('db_page_tmp: ', db_page_tmp)
        db_page_video = [i for i in db_page_tmp if i.startswith('/video/')]
        
        db_page_ps = [i for i in db_page_tmp if i.startswith('/pornstar/')]
        ps1 = [h.split('/')[-1].replace('-','_') for h in db_page_ps[::2]]
        ps2 = [h.split('/')[-1].replace('-', '_') for h in db_page_ps[1::2]]
        
        title = [h.split('/')[-1].replace('-', '_') for h in db_page_video[::2]]
        #print('title: ', title)
        site_tmp = [site_name]
        #print('site_tmp: ', site_name)
        site = list(site_tmp) * 24
        #print('site: ', site)
        
        
        ps1_db = pd.DataFrame(ps1)
        ps2_db = pd.DataFrame(ps2)
        title_db = pd.DataFrame(title)
        site_db = pd.DataFrame(site)
        
        db_all_tmp = pd.concat([site_db, ps1_db, ps2_db, title_db], axis=1)
        custom_cols = ['Site', 'PS1', 'PS2', 'Title']
        #print('db_all_tmp: ', db_all_tmp)
        db_all_tmp.columns = custom_cols
        db_actual_site_name = pd.concat([db_actual_site_name, db_all_tmp])
        #print('db_all_tmp: ', db_all_tmp)
        #print('db_actual_site_name:\n ', db_actual_site_name)

    df_tmp = db_actual_site_name
    #print('df_tmp: ', db_actual_site_name)
    
df_1_tmp = db_actual_site_name
carmella_bing_df = df_1_tmp[df_1_tmp['PS1'].notna()]

# %%
carmella_bing_df = carmella_bing_df.reset_index(drop=True)

# %%
carmella_bing_df

# %% [markdown]
# ***

# %% [markdown]
# ### create the df_final...

# %%
df_ms = pd.read_csv('df_missing_sites.csv', index_col=[0])
# Delete the rows which contain NaN Cells in the column PS1
df_ms = df_ms[df_ms['PS1'].notna()]

df_f = pd.read_csv('final_df_11_04_2022.csv', index_col=[0])
# Delete the rows which contain NaN Cells in the column PS1
df_f = df_f[df_f['PS1'].notna()]

df_final = pd.concat([df_ms, df_f])

# Reset the index... 
df_final = df_final.reset_index()
del df_final['index']

df_final.to_csv('df_final_inklusive_ms.csv')

# %% [markdown]
# ***

# %% [markdown]
# ### Comparison of df_final and my_db...

# %% [markdown]
# Load the df_final

# %%
import pandas as pd
df_final = pd.read_csv('df_final_inklusive_ms.csv', index_col=[0])

# %% [markdown]
# Load my_db and slicing to a adequate format.

# %%
import pandas as pd

# %%
df_my_db = pd.read_csv('df_final_my_db_py_11_07_2022.csv', index_col=[0])

# %%
df_my_db[(df_my_db['Site'] == "Doctor Adventures") & (df_my_db['PS1'] == "Carmella Bing")]

# %%
# make the column "Title" comparable with the Title-column of df_final
title_only = ['_'.join(x.split('_')[:-1]) for x in df_my_db['Title']]
df_my_db['Title'] = title_only
del df_my_db['Location']
del df_my_db['Link']

# %% [markdown]
# Look, which titles of my_db are in the df_final..

# %% [markdown]
# ### Reduce the df by choosen PS!

# %%
chosen_ps = "Carmella Bing"
reduced_df_by_ps = df_my_db[(df_my_db['PS1'] == chosen_ps) | (df_my_db['PS2'] == chosen_ps) | (df_my_db['PS3'] == chosen_ps) | \
                            (df_my_db['PS4'] == chosen_ps) | (df_my_db['PS5'] == chosen_ps) | (df_my_db['PS6'] == chosen_ps) | \
                            (df_my_db['PS7'] == chosen_ps) | (df_my_db['PS8'] == chosen_ps) | (df_my_db['PS9'] == chosen_ps) | \
                            (df_my_db['PS10'] == chosen_ps)]

# %%
reduced_df_by_ps

# %%
my_df_cb_title = reduced_df_by_ps['Title']

# %%
carmella_bing_df

# %%
my_df_cb_title

# %%
carmella_bing_df['in_my_db'] = 'No'
for single_title in reduced_df_by_ps['Title']:
    for cb_title in carmella_bing_df['Title']:
        if cb_title == single_title:
            print('cb_title: ', cb_title)
            #index_found = reduced_df_by_ps[reduced_df_by_ps['Title']==cb_title].index.item()
            index_found_cb_df = carmella_bing_df[carmella_bing_df['Title']==cb_title].index.item()
            #print('found at my_df index: ',  str(index_found))
            print('found at cb_df_index: ', str(index_found_cb_df))
            carmella_bing_df.loc[index_found_cb_df,'in_my_db'] = 'Yes'

# %%
carmella_bing_df[carmella_bing_df['in_my_db'] == 'No'][['Title']]

# %%
carmella_bing_df.loc[10,'in_my_db'] = 'Yes'

# %%
carmella_bing_df

# %%
#for cb_title in carmella_bing_df['Title']:
#    print(cb_title)
carmella_bing_df['Title']

# %%
reduced_df_by_ps['Title']

# %%
df_my_db.iloc[1582,:]

# %%
df_final['available_in_my_db'] = 'no'

# %%
# The code below cost a lot of time. How can I accelerate these two for-loops?
# Trying at the bottom.... not yet????

# %%
# %%time

for index_df_final, row_df_final in df_final.iloc[:].iterrows():
    for index_my_db, row_my_db in df_my_db.iterrows():
        if row_my_db['Title'] == row_df_final['Title']:
            df_final.loc[index_df_final, 'available_in_my_db'] = 'yes'

#time_start = datetime.datetime.now()
#print('time_start: ', time_start)

# %% [markdown]
# ***

# %% [markdown]
# ## Another try: With fuzzywuzzy...

# %%
# Since the code at the upper cell cost so much time, I save this in a csv
# df_final.to_csv('df_final_adjustment_my_db.csv')

# %%
# Reading my_db and df_final..
# df_final_ad = pd.read_csv('df_final_adjustment_my_db.csv', index_col=[0])
# --> this df_final_ad is the first result of the comparision between my_db and df_final
# BUT: There are also missing titles...
# Therefore another algorithm will be tried

# %%
df_my_db = pd.read_csv('df_final_my_db_py_19_04_2022.csv', index_col=[0])
df_final = pd.read_csv('df_final_inklusive_ms.csv', index_col=[0])

# %%
my_db_title_only = ['_'.join(x.split('_')[:-1]) for x in df_my_db['Title']]
df_final_title_only = [x for x in df_final['Title']]

# %% [markdown]
# Trying to calculate the fuzzy_value and writing this into a dataframe....

# %%
from fuzzywuzzy import fuzz

# %%
# %%time

df_final_title = []
my_db_title =[]
index_df_final = []
index_my_db = []
fuzz_val = []

for lf_f in df_final_title_only[:]:
    for lf_m in my_db_title_only[:]:
        val = fuzz.ratio(lf_f, lf_m)
        if val > 90:
            #print('val: ', val)
            fuzz_val.append(val)
            
            #print('lf_f: ', lf_f)
            df_final_title.append(lf_f)
            
            #print('lf_f_index: ', df_final_title_only.index(lf_f))
            index_df_final.append(df_final_title_only.index(lf_f))
            
            #print('lf_m: ', lf_m)
            my_db_title.append(lf_m)
            
            #print('lf_m_index: ', my_db_title_only.index(lf_m))
            index_my_db.append(my_db_title_only.index(lf_m))
            
            #print('===')

compare_db = {'df_final_title': df_final_title, 'index_df_final': index_df_final, 'my_db_title': my_db_title, 'index_my_db': index_my_db, 'fuzzy_value': fuzz_val}  
#columns = ['df_final_title', 'index_df_final', 'my_db_title', 'index_my_db', 'fuzzy_value']
#compare_db[columns]

# %%
compare_db = pd.DataFrame.from_dict(compare_db)

# %%
len(compare_db['fuzzy_value'])

# %% [markdown]
# Looking the Titles, for which the fuzzy_value is between 90 and 100
# These Titles are at different names in my_db compared to the df_final
# and need to be re-named!
# The counts are 346

# %%
#compare_db[compare_db['fuzzy_value'] !=100]

# %% [markdown]
# make a deepcopy of the 'original' compare_db...

# %%
import copy
compare_db_backup = copy.deepcopy(compare_db)

# %%
compare_db['edited'] = 'no'

# %%
df_compare_db_14_04_22 = compare_db[compare_db['fuzzy_value'] != 100]

# %%
# For sureness... This csv-file can be loaded and edited further...
df_compare_db_14_04_22.to_csv('df_compare_db_14_04_22.csv')

# %%
compare_db = pd.read_csv('df_compare_db_14_04_22.csv', index_col=[0])

# %%
compare_db[compare_db['fuzzy_value'] != 100][199:300]

# %% [markdown]
# #### Look in `my_db`for Title and Site-Information...

# %%
df_my_db.iloc[1524], df_final.iloc[9373]

# %%
df_final.iloc[3352]

# %%
compare_db[compare_db['fuzzy_value'] != 100][89:105].index.values

# %%
# get indices of the chosen area...
indxs = compare_db[compare_db['fuzzy_value'] != 100][89:105].index.values

# %% [markdown]
# Now, look at the indices and change the "edited" value by hand...

# %%
# indxs is the list of the indices of the chosen area...
compare_db.loc[indxs, 'edited'] = 'yes'
#df_2.iloc[1439]# , 'PS2']

# %% [markdown]
# ### Look in `my_db` for the Title and Site Information

# %%
ps_str = ""
title_string = 'moms_house_moms_rule'
#df_2[df_2['PS1'].str.contains(substr)]
df_my_db[df_my_db['PS1'].str.contains(ps_str) & df_my_db['Title'].str.contains(title_string)]

# %%
dont_touch_her_3

# %% [markdown]
# ### Look in `df_final` for Title...

# %%
ps_str = ""
title_string = 'wanderlust'
#df_2[df_2['PS1'].str.contains(substr)]
df_final[df_final['PS1'].str.contains(ps_str) & df_final['Title'].str.contains(title_string)]

# %%
len(df_final_ad[df_final_ad['available_in_my_db'] == 'yes'])

# %%
# Counting the Titles, which are in df_final AND in my_db...
len_title_df_final = len(df_final_ad[df_final_ad['available_in_my_db'] == 'yes'])
len_my_db = len(df_my_db['Title'])
# There is a difference: len_df_my_db - len_title_df_final
print('len_my_db: ', len_my_db)
print('len_title_df_final: ', len_title_df_final)

# Difference: 
diff = len_my_db - len_title_df_final
print('diff: ', diff)

# %%
len(df_final_ad[df_final_ad['available_in_my_db'] == 'yes'])

# %% [markdown]
# Try another method....

# %%
from difflib import SequenceMatcher
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
my_db_title_only[219:223]

# %%
my_db_title_only = [x for x in df_my_db['Title']]
df_final_title_only = ['_'.join(x.split('_')[:-1]) for x in df_final['Title']]

# %%
# %%time
for i in range(1, 10):
    print(i)

# %%
# %lsmagic

# %%
len(df_final_title_only), len(my_db_title_only)

# %%
# %%time

df_final_title = []
my_db_title =[]
index_df_final = []
index_my_db = []
fuzz_val = []

for lf_f in df_final_title_only[:]:
    for lf_m in my_db_title_only[:]:
        val = fuzz.ratio(lf_f, lf_m)
        if val > 90:
            #print('val: ', val)
            fuzz_val.append(val)
            
            #print('lf_f: ', lf_f)
            df_final_title.append(lf_f)
            
            #print('lf_f_index: ', df_final_title_only.index(lf_f))
            index_df_final.append(df_final_title_only.index(lf_f))
            
            #print('lf_m: ', lf_m)
            my_db_title.append(lf_m)
            
            #print('lf_m_index: ', my_db_title_only.index(lf_m))
            index_my_db.append(my_db_title_only.index(lf_m))
            
            #print('===')

compare_db = {'df_final_title': df_final_title, 'index_df_final': index_df_final, 'my_db_title': my_db_title, 'index_my_db': index_my_db, 'fuzzy_value': fuzz_val}  
#columns = ['df_final_title', 'index_df_final', 'my_db_title', 'index_my_db', 'fuzzy_value']
#compare_db[columns]

# %%
compare_db = pd.DataFrame.from_dict(compare_db)

# %%
compare_db[compare_db['fuzzy_value'] != 100]

# %%
from fuzzywuzzy import fuzz

# %%
fuzz.ratio("check out this example", "check out this exampel")

# %%
# %%time

match_value_list = []
similar_indices = []
match_val = []
for index_df_final, row_df_final in df_final.iloc[197:3210].iterrows():
    for index_my_db, row_my_db in df_my_db[775:780].iterrows():

        match_val = similar(row_my_db['Title'], row_df_final['Title'])
        match_value_list.append(match_val)
        similar_indices.append(index_df_final)
        
        #if match_val >= 0.95:
            
#print('similar_indices: ', similar_indices)
        #similar_value.append(similar(row_my_db['Title'], row_df_final['Title']))
    #print('similar_vlaue: ', similar_value)
        # if row_my_db['Title'] == row_df_final['Title']:
         #    df_final.loc[index_df_final, 'available_in_my_db'] = 'yes'

# %%
pwd

# %%
from collections import Counter

l = match_value_list
Counter(l)#.most_common(1)

# %%
max(match_value_list)

# %%
ps_str = ""
substr_2 = 'shes_a_smooth_operator'
#df_2[df_2['PS1'].str.contains(substr)]
df_my_db[df_my_db['PS1'].str.contains(ps_str) & df_my_db['Title'].str.contains(substr_2)]

# %%
df_my_db[775:780]['Title']

# %%
df_final.loc[[200, 628, 1290], 'Title']

# %% [markdown]
# Load my bra_db and compare this with the title-occurance within the df_final

# %% [markdown]
# ### Load the special df of favourite PS... example: jasmine jae

# %%
df_jj = pd.read_csv('df_jj.csv', index_col=[0])

# %%
df_jj.tail()

# %% [markdown]
# Preparation: increase the column of df_jj for availability of the title within the df_final

# %%
df_jj['df_final_av'] = 'no'

# %%
# Look at the appearance of the titles in df_jj and df_f
for index_jj, row_jj in df_jj.iterrows():
    for index_df_f, row_df_f in df_final.iterrows():
        if row_df_f['Title'] == row_jj['Title']:
            df_jj.loc[index_jj, 'df_final_av'] = 'yes'

# %%
df_jj

# %%
df_jj['df_final_av'].value_counts()

# %%
df_final[df_final['Title']== 'four_hands_to_jerk_the_clerk']

# %%
df_ms = pd.read_csv('df_missing_sites.csv', index_col=[0])

# %%
for index_jj, row_jj in df_jj.iterrows():
    for index_df_f, row_df_f in df_ms.iterrows():
        if row_df_f['Title'] == row_jj['Title']:
            df_jj.loc[index_jj, 'av_in_df_f'] = 'yes'

# %% [markdown]
# ***

# %% [markdown]
# ### Next step: Load my bra_db and compare this with the PS-occurance and with the complete database...

# %%
df_my_db = pd.read_csv('df_final_my_db_py.csv', index_col=[0])
df_final = pd.read_csv('df_final_inklusive_ms.csv', index_col=[0])

# %%
title_only = ['_'.join(x.split('_')[:-1]) for x in df_my_db['Title']]

# %%
df_my_db['Title'] = title_only

# %%
df_my_db_sliced = df_my_db

# %%
del df_my_db_sliced['Location']
del df_my_db_sliced['Link']

# %%
df_my_db

# %% [markdown]
# ***

# %% [markdown]
# #### Look, which titles of my_db are in the final_df...

# %%
df_final['available_in_my_db'] = 'no'

# %%
for index_df_final, row_df_final in df_final.iloc[:].iterrows():
    for index_my_db, row_my_db in df_my_db_sliced.iterrows():
        if row_my_db['Title'] == row_df_final['Title']:
            df_final.loc[index_df_final, 'available_in_my_db'] = 'yes'

# %%
len(df_final[df_final['available_in_my_db'] == 'yes'])

# %%
len(df_my_db_sliced)

# %% [markdown]
# ***

# %% [markdown]
# The other way ....

# %% [markdown]
# #### Look, which titles of final_db are in my_db...

# %%
df_my_db_sliced['available_in_df_final'] = 'no'

# %%
# This cost a lot of time. How can I accelerate these two for-loops?
# Trying at the bottom....
for index_my_db, row_my_db in df_my_db_sliced.iloc[:].iterrows():
    for index_df_final, row_df_final in df_final.iterrows():
        if row_df_final['Title'] == row_my_db['Title']:
            df_my_db_sliced.loc[index_my_db, 'available_in_df_final'] = 'yes'

# %% [markdown]
# ***

# %% [markdown]
# There is a difference between titles within my_db and df_final, although I guess I have downloaded it.

# %%
df_my_db_sliced[df_my_db_sliced['available_in_df_final'] == 'no']
len(df_my_db_sliced[df_my_db_sliced['available_in_df_final'] == 'no'])

# %% [markdown]
# looking for instance at jasmine jae....

# %%
df_temp_1 = df_my_db_sliced[(df_my_db_sliced['PS1'] == 'Jasmine Jae') & (df_my_db_sliced['available_in_df_final'] == 'no')]

# %%
df_temp_2 = df_final[(df_final['PS1'] == 'jasmine_jae') & (df_final['available_in_my_db'] == 'no')]

# %%
list_df_final = df_temp_2.loc[[2927, 3060, 7925, 7747, 8444], 'Title']

# %%
list_my_db = df_temp_1.loc[[320, 321, 1326, 1327, 1468], 'Title']

# %%
df_temp_1

# %%
list_df_final

# %%
sim = []
for li1, li2 in zip(list_df_final, list_my_db):
    print(li2)
    sim.append(similar(li1, li2))

# %%
sim

# %%
list_my_db = df_temp_1.loc[[320, 321, 1326, 1327, 1468], 'Title']

# %%
df_final.columns

# %%
df_final['Title']

# %% [markdown]
# looking at index 1245... for instance.

# %%
ps_str = ""
substr_2 = 'the_dick_pic_trick'
#df_2[df_2['PS1'].str.contains(substr)]
df_my_db[df_my_db['PS1'].str.contains(ps_str) & df_my_db['Title'].str.contains(substr_2)]

# %%
my_db_list_title_column = [x for x in df_my_db_sliced['Title']]
df_final_title_column = [x for x in df_final['Title']]
#for index_my_db, row_my_db in df_my_db_sliced.iloc[200:220].iterrows():
#    print('row_my_db', row_my_db)

# %%
len(df_final_title_column)

# %%
df_final_title_column[-10:]

# %%
list1 = ['little','blue','widget']
list2 = ['there','is','a','little','blue','cup','on','the','table']

list3 = set(list1) & set(list2)

list4 = sorted(list3, key = lambda k : list1.index(k))

# %%
list4

# %%
from difflib import SequenceMatcher
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
similar("his_best_friend_s_bedding","his_best_friends_bedding")

# %%
for index_my_db, row_my_db in df_my_db_sliced.iloc[200:400].iterrows():
    for index_df_final, row_df_final in df_final.iterrows():
        if row_df_final['Title'] == row_my_db['Title']:
            df_my_db_sliced.loc[index_my_db, 'available_in_df_final'] = 'yes'

# %%
from tqdm import tqdm

# %%
# %%time

for row in tqdm(my_df.values[:10]):
    print('my_df.index[0]', my_df.row.index)
    print('row[0]', row[0])
    temp = row[0] + row[1]
    temp = temp**2

# %%
import numpy as np
my_df = pd.DataFrame({'col_a': range(1, 10000000), 'col_b': np.sqrt(range(1, 10000000))})

# %%
df_final[df_final['']]

# %%
my_df

# %%
234*12

# %%
import sqlalchemy
from sqlalchemy.ext.declarative import declarative_base

# %%
# Define the MariaDB engine using MariaDB Connector/Python
engine = sqlalchemy.create_engine("mariadb+mariadbconnector://db_user:pax123!@192.168.178.48:3306/company")

# %% [markdown]
# ### Abbey Brooks

# %%
chosen_ps = "Abbey Brooks"
chosen_model_abbey_brooks = ['https://www.brazzers.com/videos/models/495/abbey-brooks/page/']
max_page_len_of_sites_ab = [1]

# %%
import pandas as pd
page_content_db = pd.DataFrame()
page_number_db = {}
page_content_tmp = {}
page_columns = []
ps1_db = pd.DataFrame()
ps2_db = {}
title_db = {}
db_actual_site_name = pd.DataFrame()
db_final_tmp = pd.DataFrame()
db_actual_site_name_sliced = pd.DataFrame()

# Determination of the maximum number of pages
# for lf_root in db_sites[12:13]:
#     db_page_tmp_2 = scan_func(lf_root)
#     db_page_tmp_2 = [i for i in db_page_tmp if i.startswith('/videos/site/')]
#         print('db_page_tmp: ', db_page_tmp_2)

        
        
for root_site, number in zip(chosen_model_abbey_brooks[:], max_page_len_of_sites_ab):
    print('max..' , number)
  

    # max_page_number = math.ceil(int(number) / 24)
       
    for page_nr in range(1, int(number) + 1):
        print('page_nr: ', page_nr)
        actual_site = root_site + str(page_nr)
        site_name = actual_site.split('/')[-5].replace('-', ' ').title()
            
        #print('site_name: ', site_name)
        db_page_tmp = scan_func(actual_site)
        #print('db_page_tmp: ', db_page_tmp)
        db_page_video = [i for i in db_page_tmp if i.startswith('/video/')]
        
        db_page_ps = [i for i in db_page_tmp if i.startswith('/pornstar/')]
        ps1 = [h.split('/')[-1].replace('-','_') for h in db_page_ps[::2]]
        ps2 = [h.split('/')[-1].replace('-', '_') for h in db_page_ps[1::2]]
        
        title = [h.split('/')[-1].replace('-', '_') for h in db_page_video[::2]]
        #print('title: ', title)
        site_tmp = [site_name]
        #print('site_tmp: ', site_name)
        site = list(site_tmp) * 24
        #print('site: ', site)
        
        
        ps1_db = pd.DataFrame(ps1)
        ps2_db = pd.DataFrame(ps2)
        title_db = pd.DataFrame(title)
        site_db = pd.DataFrame(site)
        #print('Site_db: ', site_db)
        db_all_tmp = pd.concat([site_db, ps1_db, ps2_db, title_db], axis=1)
        custom_cols = ['Site', 'PS1', 'PS2', 'Title']
        #print('db_all_tmp: ', db_all_tmp)
        db_all_tmp.columns = custom_cols
        db_actual_site_name = pd.concat([db_actual_site_name, db_all_tmp])
        #print('db_all_tmp: ', db_all_tmp)
        #print('db_actual_site_name:\n ', db_actual_site_name)

    df_tmp = db_actual_site_name
    #print('db_actual_site_name: ', db_actual_site_name)
    
df_ab_tmp = db_actual_site_name
abbey_brooks_df = df_ab_tmp[df_ab_tmp['PS1'].notna()]
# Out:
# max.. 1
# page_nr:  1
# scanning Site: https://www.brazzers.com/videos/models/495/abbey-brooks/page/1, Response: <Response [200]>

# %%
abbey_brooks_df
# Out:
#       Site             PS1                 PS2  \
# 0   Models    abbey_brooks         tyler_nixon
# 1   Models  jillian_janson        abbey_brooks
# 2   Models     bridgette_b        abbey_brooks
# 3   Models    abbey_brooks         tasha_reign
# 4   Models    abbey_brooks          toni_ribas
# 5   Models    abbey_brooks      danny_mountain
# 6   Models    abbey_brooks       phoenix_marie
# 7   Models    abbey_brooks           mick_blue
# 8   Models    abbey_brooks         johnny_sins
# 9   Models    abbey_brooks         scott_nails
# 10  Models    abbey_brooks         scott_nails
# 11  Models    abbey_brooks         scott_nails
# 12  Models    abbey_brooks  kagney_linn_karter
# 13  Models    abbey_brooks          keiran_lee
# 14  Models    abbey_brooks       chris_strokes
# 15  Models    abbey_brooks   charisma_cappelli
# 16  Models    abbey_brooks         gianna_lynn
# 17  Models    abbey_brooks     rhylee_richards
# 18  Models    eva_angelina        abbey_brooks
# 19  Models    abbey_brooks         nick_dundee
# 20  Models    abbey_brooks        charles_dera
# 21  Models    abbey_brooks      derrick_pierce
#
#                               Title
# 0          show_me_how_you_jerk_off
# 1       this_is_how_you_get_the_job
# 2                     truth_or_dare
# 3   brazzers_live_34_bigger_blonder
# 4           show_me_what_you_can_do
# 5                cultural_fetishism
# 6                 war_wives_get_wet
# 7                 language_banguage
# 8               mommys_got_a_secret
# 9                  talk_dirty_to_me
# 10                   fuck_the_prick
# 11          taking_care_of_the_team
# 12                 cock_of_immunity
# 13                     twinkle_tits
# 14   agent_brooks_captures_the_cock
# 15                        powerfuck
# 16               big_cock_car_chase
# 17               sexy_sunday_school
# 18     people_vs_pornstarslikeitbig
# 19                 algebra_homework
# 20                        late_fees
# 21                   extra_benefits

# %%
df_top56_ps = pd.read_csv('df_top56_ps_tmp_08_08_22.csv', index_col=[0])

# %%
df_top56_ps[df_top56_ps['PS1'] == 'Abbey Brooks']
# Out:
#                        Site           PS1                PS2  \
# 99       Big Tits At School  Abbey Brooks            No Name
# 245        Big Tits At Work  Abbey Brooks            No Name
# 246        Big Tits At Work  Abbey Brooks            No Name
# 247        Big Tits At Work  Abbey Brooks            No Name
# 443      Big Tits In Sports  Abbey Brooks            No Name
# 950       Milfs Like It Big  Abbey Brooks            No Name
# 1230        Moms In Control  Abbey Brooks     Jillian Janson
# 1258  Pornstars Like It Big  Abbey Brooks        Bridgette B
# 1259  Pornstars Like It Big  Abbey Brooks  Kagneylinn Karter
# 1258  Pornstars Like It Big  Abbey Brooks        Bridgette B
#
#                                   Title      PS3      PS4      PS5      PS6  \
# 99             cultural_festishism_720p  No Name  No Name  No Name  No Name
# 245          handling_his_business_720p  No Name  No Name  No Name  No Name
# 246              language_banguage_720p  No Name  No Name  No Name  No Name
# 247           sensitivity_training_720p  No Name  No Name  No Name  No Name
# 443        taking_care_of_the_team_720p  No Name  No Name  No Name  No Name
# 950             the_butler_did_her_720p  No Name  No Name  No Name  No Name
# 1230  this_is_how_you_get_the_job_1080p  No Name  No Name  No Name  No Name
# 1258                 truth_or_dare_720p  No Name  No Name  No Name  No Name
# 1259              cock_of_immunity_720p  No Name  No Name  No Name  No Name
# 1258                 truth_or_dare_720p  No Name  No Name  No Name  No Name
#
#           PS7      PS8      PS9     PS10    Location  \
# 99    No Name  No Name  No Name  No Name  WERDERNASX
# 245   No Name  No Name  No Name  No Name  WERDERNASX
# 246   No Name  No Name  No Name  No Name  WERDERNASX
# 247   No Name  No Name  No Name  No Name  WERDERNASX
# 443   No Name  No Name  No Name  No Name  WERDERNASX
# 950   No Name  No Name  No Name  No Name  WERDERNASX
# 1230  No Name  No Name  No Name  No Name  WERDERNASX
# 1258  No Name  No Name  No Name  No Name  WERDERNASX
# 1259  No Name  No Name  No Name  No Name  WERDERNASX
# 1258  No Name  No Name  No Name  No Name  WERDERNASX
#
#                                                    Link
# 99    /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 245   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 246   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 247   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 443   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 950   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/milfs_lik...
# 1230  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/moms_in_c...
# 1258  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 1259  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 1258  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...

# %%
df_complete[df_complete['PS1'] == 'Abbey Brooks']
# Out:
#                        Site           PS1                PS2  \
# 99       Big Tits At School  Abbey Brooks            No Name
# 245        Big Tits At Work  Abbey Brooks            No Name
# 246        Big Tits At Work  Abbey Brooks            No Name
# 247        Big Tits At Work  Abbey Brooks            No Name
# 443      Big Tits In Sports  Abbey Brooks            No Name
# 950       Milfs Like It Big  Abbey Brooks            No Name
# 1230        Moms In Control  Abbey Brooks     Jillian Janson
# 1258  Pornstars Like It Big  Abbey Brooks        Bridgette B
# 1259  Pornstars Like It Big  Abbey Brooks  Kagneylinn Karter
# 1568     Big Tits At School  Abbey Brooks            No Name
# 1569     Big Tits At School  Abbey Brooks    Rhylee Richards
# 1580       Big Tits At Work  Abbey Brooks            No Name
# 1587     Big Tits In Sports  Abbey Brooks  Charisma Cappelli
# 1592          Big Wet Butts  Abbey Brooks            No Name
# 1678          Dirty Masseur  Abbey Brooks            No Name
# 1694        Mommy Got Boobs  Abbey Brooks            No Name
# 1695        Mommy Got Boobs  Abbey Brooks            No Name
# 1708  Pornstars Like It Big  Abbey Brooks       Eva Angelina
# 1709  Pornstars Like It Big  Abbey Brooks        Gianna Lynn
# 1721      Real Wife Stories  Abbey Brooks            No Name
#
#                                   Title           PS3           PS4      PS5  \
# 99             cultural_festishism_720p       No Name       No Name  No Name
# 245          handling_his_business_720p       No Name       No Name  No Name
# 246              language_banguage_720p       No Name       No Name  No Name
# 247           sensitivity_training_720p       No Name       No Name  No Name
# 443        taking_care_of_the_team_720p       No Name       No Name  No Name
# 950             the_butler_did_her_720p       No Name       No Name  No Name
# 1230  this_is_how_you_get_the_job_1080p       No Name       No Name  No Name
# 1258                 truth_or_dare_720p       No Name       No Name  No Name
# 1259              cock_of_immunity_720p       No Name       No Name  No Name
# 1568                     late_fees_480p       No Name       No Name  No Name
# 1569            sexy_sunday_school_480p       No Name       No Name  No Name
# 1580                extra_benefits_480p       No Name       No Name  No Name
# 1587                     powerfuck_480p       No Name       No Name  No Name
# 1592              talk_dirty_to_me_720p       No Name       No Name  No Name
# 1678       show_me_what_you_can_do_480p       No Name       No Name  No Name
# 1694           mommys_got_a_secret_480p       No Name       No Name  No Name
# 1695           show_me_how_you_jerk_off       No Name       No Name  No Name
# 1708  people_vs_pornstarslikeitbig_480p  Puma Schwede  Rachel Starr  No Name
# 1709            big_cock_car_chase_480p       No Name       No Name  No Name
# 1721               fuck_that_prick_720p       No Name       No Name  No Name
#
#           PS6      PS7      PS8      PS9     PS10     Location  \
# 99    No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 245   No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 246   No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 247   No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 443   No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 950   No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 1230  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 1258  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 1259  No Name  No Name  No Name  No Name  No Name   WERDERNASX
# 1568  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1569  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1580  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1587  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1592  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1678  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1694  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1695  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1708  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1709  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
# 1721  No Name  No Name  No Name  No Name  No Name  WERDERNAS2X
#
#                                                    Link
# 99    /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 245   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 246   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 247   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 443   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/big_tits_...
# 950   /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/milfs_lik...
# 1230  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/moms_in_c...
# 1258  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 1259  /Volumes/WERDERNASX/VIDEOSX/BRAZZERS/pornstars...
# 1568  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/big_ti...
# 1569  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/big_ti...
# 1580  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/big_ti...
# 1587  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/big_ti...
# 1592  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/big_we...
# 1678  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/dirty_...
# 1694  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/mommy_...
# 1695  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/mommy_...
# 1708  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/pornst...
# 1709  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/pornst...
# 1721  /Volumes/WERDERNAS2X/VIDEOS2X/BRAZZERS2/real_w...
